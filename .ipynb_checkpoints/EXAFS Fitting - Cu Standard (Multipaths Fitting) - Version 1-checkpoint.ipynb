# %%
from larch import Group
from larch.xafs import feffit, feffit_dataset, feffit_transform, feffit_report
from larch.xafs import autobk, xftf, xftr, ff2chi, feffpath
from larch.fitting import  param_group, param
from larch.io import read_ascii

import os
import h5py
import numpy as np
import matplotlib.pyplot as plt
# Out:
# [root] WARNING : Larchs apps and shell are not supported due to missing dependencies: cannot import name 'LarchWxApp' from 'larch.wxlib' (D:\Python\Anaconda3\envs\xraylarch\lib\site-packages\larch\wxlib\__init__.py)

# %%
""" 
--- Cu Standard EXAFS Fitting w/ Multiple Scattering Paths --- 

Data Reading and Pre-processing

Notes: 
1.  Data is read from .nxs file and loaded into a larch group from scratch.

2.  The data loaded was normalised via DAWN. To suppress auto-normalisation in Larch, 
    the pre_edge_kws are added to force a 1st degree polynomial fit for post-edge.
    
WIP: define data directly as normalised data

"""
file_path = "data\\exafs_fitting\\Cu_foil_STD_merge_norm.nxs" # Normalised .nxs file

# Reading .nxs by h5py
file = h5py.File(file_path, "r")
energy = np.array(file["processed"]["result"]["energy"])
data = np.array(file["processed"]["result"]["data"])

# Loading into a larch group and autobk (see note 2)
std_cu = Group(name="Cu Standard", energy=energy, mu=data)
autobk(std_cu, pre_edge_kws={"nnorm": 0, "nvict": 0}, rbkg=1.0)

# %%
""" Misc: Inspecting the suppressed normalisation result. """
energy = std_cu.energy

fig = plt.figure(figsize=(10, 7))

plt.plot(energy, std_cu.mu, label='DAWN-normalised')
plt.plot(energy, std_cu.norm, label='suppressed-normalised')
plt.plot(energy, std_cu.pre_edge, label='pre-edge line')
plt.plot(energy, std_cu.post_edge, label='post-edge curve')
plt.axhline(1, linestyle=":", color="k")

plt.legend()
plt.xlabel("Energy (eV)")
plt.ylabel("Absorption")
# Out:
# Text(0, 0.5, 'Absorption')

# %%
""" 
Set Up Scattering Path Files

The Cu paths generated by previous feff calculations are used. (See "Demonstration - Feff Calculation.ipynb")

"""

# Inspect scattering path files
from tools import get_feff_info as finfo

feff_folder = "C:\\Users\\user\\larch\\feff\\Cu1_K_Copper_cif11145\\"
info = finfo.get_path_info(feff_folder)
info
# Out:
# files.dat found, returning dataframe.
#             file  sig2  amp ratio   deg  nlegs  r effective
# 0   feff0001.dat   0.0    100.000  12.0      2       2.5562
# 1   feff0002.dat   0.0     22.990   6.0      2       3.6150
# 2   feff0003.dat   0.0     12.310  48.0      3       3.8342
# 3   feff0004.dat   0.0      9.392  48.0      3       4.3636
# 4   feff0005.dat   0.0     55.800  24.0      2       4.4274
# 5   feff0006.dat   0.0     11.750  48.0      3       4.7699
# 6   feff0007.dat   0.0     25.390  96.0      3       4.7699
# 7   feff0008.dat   0.0     19.160  12.0      2       5.1123
# 8   feff0009.dat   0.0      9.608  12.0      3       5.1123
# 9   feff0010.dat   0.0     44.490  24.0      3       5.1123
# 10  feff0011.dat   0.0      9.657  12.0      4       5.1123
# 11  feff0012.dat   0.0      4.445  12.0      4       5.1123
# 12  feff0014.dat   0.0     32.280  12.0      4       5.1123
# 13  feff0015.dat   0.0      2.750  48.0      4       5.1123
# 14  feff0016.dat   0.0      4.621  48.0      3       5.2993
# 15  feff0017.dat   0.0     28.260  24.0      2       5.7158
# 16  feff0018.dat   0.0      9.809  48.0      3       5.9434
# 17  feff0019.dat   0.0      7.760  48.0      3       5.9434
# 18  feff0020.dat   0.0      8.455  48.0      3       5.9434
# 19  feff0021.dat   0.0      5.691  96.0      3       6.0479
# 20  feff0022.dat   0.0      5.733  96.0      3       6.0479
# 21  feff0023.dat   0.0      5.743  96.0      4       6.0479
# 22  feff0024.dat   0.0      6.140  96.0      4       6.0479
# 23  feff0027.dat   0.0      7.285   8.0      2       6.2613
# 24  feff0028.dat   0.0      6.890  96.0      3       6.3497
# 25  feff0029.dat   0.0      4.558  48.0      3       6.6224
# 26  feff0030.dat   0.0      4.138  48.0      3       6.6224
# 27  feff0031.dat   0.0      4.236  48.0      3       6.6224
# 28  feff0032.dat   0.0     34.960  48.0      2       6.7630
# 29  feff0033.dat   0.0     18.780  96.0      3       6.8733
# 30  feff0034.dat   0.0     14.970  96.0      3       6.8733
# 31  feff0035.dat   0.0     13.790  96.0      3       6.8733
# 32  feff0036.dat   0.0      4.246  96.0      4       6.9836
# 33  feff0037.dat   0.0      4.416  96.0      4       6.9836
# 34  feff0040.dat   0.0      5.797  96.0      4       6.9836
# 35  feff0043.dat   0.0      5.022  96.0      4       6.9836

# %%
""" Set up feffit for EXAFS Fitting. (1) """

# Define Fourier transform and fitting space (Actual FT parameters for EXAFS fitting)
_feffit_trans = feffit_transform(kmin=3.000, kmax=15.000, dk=1.0000, kw=2,
                                 window="hanning", fitspace='r', rmin=1.000, rmax=4.000)

# %%
""" Visualised k- and R- space. """
xftf(std_cu, kmin=3.000, kmax=15.000, dk=1.000, window="hanning", kweight=2.00, rmin=1.000, rmax=4.000)

fig, ax = plt.subplots(1, 2, figsize=(20, 7))

ax[0].plot(std_cu.k, std_cu.chi, label="k-space")
ax[0].set_ylabel("k $\chi$ (k)")
ax[0].set_xlabel("k ($\AA$)")
ax[0].set_xlim(1, 13)
ax[0].set_ylim(-0.15, 0.2)
ax[0].legend()

ax[1].plot(std_cu.r, std_cu.chir_mag, "-o", markersize=3, color="k", label="R-space")
ax[1].set_ylabel("$\chi$ (R)")
ax[1].set_xlabel("R")
ax[1].legend()

# %%
""" Set up feffit for EXAFS Fitting. (2) """
from iteration_utilities import deepflatten

# Create feffit Parameter Group to hold fit parameters (Core parameters)
_feffit_params = param_group(s02=param(1.0, min=0, vary=True),
                             e0=param(0.1, min=-25, max=25, vary=True))

# Create feffit Parameter Group to hold fit parameters (Repeating parameters)
# The paths information from "info" is referred
scatter_paths = [os.path.join(feff_folder, fname) for fname in info["file"].values[:3]]
ncucu = info["deg"].values
path_num = len(scatter_paths)

fit_params = ["n_cucu", "delr_cu", "sigma2_cu"]
def fit_constraints(n):
    constraints = [param(n, vary=False),
                   param(0.001, min=-0.5, max=0.5, vary=True),
                   param(0.008, min=0.001, max=0.009, vary=True)]
    
    return constraints

def flatten_list(_list):
    return np.array(_list).ravel().tolist()

all_fit_params = [param + str(i) for i in range(path_num) for param in fit_params]
all_fit_cons = list(deepflatten([fit_constraints(n) for i, n in zip(range(path_num), ncucu)]))

# Put organised fit parameters and constraints into feffit parameter group
for key, value in zip(all_fit_params, all_fit_cons):
    setattr(_feffit_params, key, value)

# %%
_paths_dict = {}

def generate_feffpath(file_path, label, degen, e0, sigma2, s02, deltar):
    return feffpath(file_path, label=label, degen=degen, e0=e0, sigma2=sigma2, s02=s02, deltar=deltar)
    
for i, scatter_path in enumerate(scatter_paths):
    _paths_dict["Cu" + str(i)] = generate_feffpath(scatter_path,
                                                   label="Cu"+str(i),
                                                   degen=1,
                                                   e0="e0",
                                                   sigma2="sigma2_cu"+str(i),
                                                   s02="s02 * n_cucu"+str(i),
                                                   deltar="delr_cu"+str(i))

_paths_dict
# Out:
# {'Cu0': <FeffPath Group label=Cu0, filename=C:\Users\user\larch\feff\Cu1_K_Copper_cif11145\feff0001.dat>,
#  'Cu1': <FeffPath Group label=Cu1, filename=C:\Users\user\larch\feff\Cu1_K_Copper_cif11145\feff0002.dat>,
#  'Cu2': <FeffPath Group label=Cu2, filename=C:\Users\user\larch\feff\Cu1_K_Copper_cif11145\feff0003.dat>}

# %%
_feffit_dataset = feffit_dataset(data=std_cu, transform=_feffit_trans, paths=_paths_dict)
_feffit_result = feffit(_feffit_params, _feffit_dataset)

# %%
""" Misc: Plotting fitted spectra

All (meta)data is stored within the _feffit_result group.

"""

fig = plt.figure(figsize=(10, 7))

spectra = _feffit_result.datasets[0].data
fit = _feffit_result.datasets[0].model

plt.plot(fit.r, fit.chir_mag)
plt.plot(spectra.r, spectra.chir_mag, lw=0, marker='o', markersize=3, fillstyle='none', color="k", label="Raw Data")
plt.legend()

# %%
""" 
Misc: Print fitted results.

Larch also organises the fitting results in a "feffit_report" as shown below.

"""
print(feffit_report(_feffit_result))
# Out:
# =================== FEFFIT RESULTS ====================
# [[Statistics]]
#    nvarys, npts       =  8, 190
#    n_independent      =  23.154
#    chi_square         =  960.204846
#    reduced chi_square =  63.3615893
#    r-factor           =  0.01316517
#    Akaike info crit   =  102.249169
#    Bayesian info crit =  111.386636
#
# [[Data]]
#    fit space          = 'r'
#    r-range            = 1.000, 3.900
#    k-range            = 3.000, 15.000
#    k window, dk       = 'hanning', 1.000
#    paths used in fit  = ['C:\\Users\\user\\larch\\feff\\Cu1_K_Copper_cif11145\\feff0001.dat', 'C:\\Users\\user\\larch\\feff\\Cu1_K_Copper_cif11145\\feff0002.dat', 'C:\\Users\\user\\larch\\feff\\Cu1_K_Copper_cif11145\\feff0003.dat']
#    k-weight           = 2
#    epsilon_k          = Array(mean=7.1382e-04, std=0.00108917)
#    epsilon_r          = 0.01754453
#    n_independent      = 23.154
#
# [[Variables]]
#    delr_cu0       = -0.00825220 +/- 0.00485940   (init=  1.0000e-03)
#    delr_cu1       = -7.6347e-04 +/- 0.01277787   (init=  1.0000e-03)
#    delr_cu2       = -0.07041000 +/- 0.02221139   (init=  1.0000e-03)
#    e0             =  5.99365647 +/- 0.80432165   (init=  0.10000000)
#    n_cucu0        =  12.0000000 (fixed)
#    n_cucu1        =  6.00000000 (fixed)
#    n_cucu2        =  48.0000000 (fixed)
#    s02            =  0.90835015 +/- 0.06961461   (init=  1.00000000)
#    sigma2_cu0     =  0.00899945 +/- 6.3916e-04   (init=  0.00800000)
#    sigma2_cu1     =  0.00900000 +/- 0.00122352   (init=  0.00800000)
#    sigma2_cu2     =  0.00257062 +/- 0.00408655   (init=  0.00800000)
#
# [[Correlations]]    (unreported correlations are <  0.100)
#    s02, sigma2_cu0      =  0.918
#    delr_cu0, e0         =  0.898
#    delr_cu1, e0         =  0.487
#    delr_cu0, delr_cu1   =  0.454
#    sigma2_cu1, sigma2_cu2 = -0.448
#    s02, sigma2_cu1      = -0.356
#    delr_cu1, delr_cu2   =  0.343
#    delr_cu2, e0         =  0.327
#    sigma2_cu0, sigma2_cu1 = -0.320
#    delr_cu0, delr_cu2   =  0.286
#    delr_cu2, sigma2_cu1 = -0.217
#    delr_cu1, sigma2_cu2 = -0.209
#    delr_cu0, s02        =  0.191
#    delr_cu0, sigma2_cu0 =  0.189
#    e0, sigma2_cu2       =  0.176
#    s02, sigma2_cu2      =  0.160
#    delr_cu0, sigma2_cu2 =  0.155
#    sigma2_cu0, sigma2_cu2 =  0.128
#    delr_cu1, sigma2_cu0 =  0.126
#    delr_cu2, sigma2_cu2 =  0.124
#    delr_cu1, s02        =  0.123
#
# [[Paths]]
#  = Path 'Cu0' =
#     feffdat file = C:\Users\user\larch\feff\Cu1_K_Copper_cif11145\feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#               Cu      -1.8075, -0.0000, -1.8075  1
#      reff   =  2.55620000
#      degen  =  1.00000000
#      n*s02  =  10.9002018 +/- 0.83537537  := 's02 * n_cucu0'
#      e0     =  5.99365647 +/- 0.80432165  := 'e0'
#      r      =  2.54794780 +/- 0.00485940  := 'reff + delr_cu0'
#      deltar = -0.00825220 +/- 0.00485940  := 'delr_cu0'
#      sigma2 =  0.00899945 +/- 6.3916e-04  := 'sigma2_cu0'
#
#  = Path 'Cu1' =
#     feffdat file = C:\Users\user\larch\feff\Cu1_K_Copper_cif11145\feff0002.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#               Cu      -0.0000,  3.6150, -0.0000  1
#      reff   =  3.61500000
#      degen  =  1.00000000
#      n*s02  =  5.45010089 +/- 0.41768769  := 's02 * n_cucu1'
#      e0     =  5.99365647 +/- 0.80432165  := 'e0'
#      r      =  3.61423653 +/- 0.01277787  := 'reff + delr_cu1'
#      deltar = -7.6347e-04 +/- 0.01277787  := 'delr_cu1'
#      sigma2 =  0.00900000 +/- 0.00122352  := 'sigma2_cu1'
#
#  = Path 'Cu2' =
#     feffdat file = C:\Users\user\larch\feff\Cu1_K_Copper_cif11145\feff0003.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#               Cu       1.8075, -0.0000, -1.8075  1
#               Cu       1.8075, -1.8075, -0.0000  1
#      reff   =  3.83420000
#      degen  =  1.00000000
#      n*s02  =  43.6008071 +/- 3.34150150  := 's02 * n_cucu2'
#      e0     =  5.99365647 +/- 0.80432165  := 'e0'
#      r      =  3.76379000 +/- 0.02221139  := 'reff + delr_cu2'
#      deltar = -0.07041000 +/- 0.02221139  := 'delr_cu2'
#      sigma2 =  0.00257062 +/- 0.00408655  := 'sigma2_cu2'
#
# =======================================================

# %%
"""
Misc: Fitted Parameters

Most fitted parameters are stored within _feffit_result.params, which is a "Parameters" object from the lmfit package.
See example below for extracting fitted parameters.

"""

results = _feffit_result

# Example to extract fitted parameters
label = "s02"
s02 = results.params[label].value
s02_err = results.params[label].stderr

print("---- Fitted Parameters ----")
print(label, ":", s02, "; error: ", s02_err)

# Show lmfit Parameters object
results.params
# Out:
# ---- Fitted Parameters ----
# s02 : 0.9083501487845118 ; error:  0.06961461441881409
# Parameters([('delr_cu0', <Parameter 'delr_cu0', value=-0.008252202117131568 +/- 0.00486, bounds=[-0.5:0.5]>), ('delr_cu1', <Parameter 'delr_cu1', value=-0.000763468157052416 +/- 0.0128, bounds=[-0.5:0.5]>), ('delr_cu2', <Parameter 'delr_cu2', value=-0.07040999722602559 +/- 0.0222, bounds=[-0.5:0.5]>), ('e0', <Parameter 'e0', value=5.993656465366165 +/- 0.804, bounds=[-25:25]>), ('n_cucu0', <Parameter 'n_cucu0', value=12.0 (fixed), bounds=[-inf:inf]>), ('n_cucu1', <Parameter 'n_cucu1', value=6.0 (fixed), bounds=[-inf:inf]>), ('n_cucu2', <Parameter 'n_cucu2', value=48.0 (fixed), bounds=[-inf:inf]>), ('s02', <Parameter 's02', value=0.9083501487845118 +/- 0.0696, bounds=[0:inf]>), ('sigma2_cu0', <Parameter 'sigma2_cu0', value=0.00899944979618009 +/- 0.000639, bounds=[0.001:0.009]>), ('sigma2_cu1', <Parameter 'sigma2_cu1', value=0.00899999999743938 +/- 0.00122, bounds=[0.001:0.009]>), ('sigma2_cu2', <Parameter 'sigma2_cu2', value=0.0025706244317872844 +/- 0.00409, bounds=[0.001:0.009]>), ('degen_pxstpuoxe6p', <Parameter 'degen_pxstpuoxe6p', value=1 (fixed), bounds=[-inf:inf]>), ('s02_pxstpuoxe6p', <Parameter 's02_pxstpuoxe6p', value=10.900201785414142 +/- 0.835, bounds=[-inf:inf], expr='s02 * n_cucu0'>), ('e0_pxstpuoxe6p', <Parameter 'e0_pxstpuoxe6p', value=5.993656465366165 +/- 0.804, bounds=[-inf:inf], expr='e0'>), ('ei_pxstpuoxe6p', <Parameter 'ei_pxstpuoxe6p', value=0.0 (fixed), bounds=[-inf:inf]>), ('deltar_pxstpuoxe6p', <Parameter 'deltar_pxstpuoxe6p', value=-0.008252202117131568 +/- 0.00486, bounds=[-inf:inf], expr='delr_cu0'>), ('sigma2_pxstpuoxe6p', <Parameter 'sigma2_pxstpuoxe6p', value=0.00899944979618009 +/- 0.000639, bounds=[-inf:inf], expr='sigma2_cu0'>), ('third_pxstpuoxe6p', <Parameter 'third_pxstpuoxe6p', value=0.0 (fixed), bounds=[-inf:inf]>), ('fourth_pxstpuoxe6p', <Parameter 'fourth_pxstpuoxe6p', value=0.0 (fixed), bounds=[-inf:inf]>), ('degen_pow2eqewd23', <Parameter 'degen_pow2eqewd23', value=1 (fixed), bounds=[-inf:inf]>), ('s02_pow2eqewd23', <Parameter 's02_pow2eqewd23', value=5.450100892707071 +/- 0.418, bounds=[-inf:inf], expr='s02 * n_cucu1'>), ('e0_pow2eqewd23', <Parameter 'e0_pow2eqewd23', value=5.993656465366165 +/- 0.804, bounds=[-inf:inf], expr='e0'>), ('ei_pow2eqewd23', <Parameter 'ei_pow2eqewd23', value=0.0 (fixed), bounds=[-inf:inf]>), ('deltar_pow2eqewd23', <Parameter 'deltar_pow2eqewd23', value=-0.000763468157052416 +/- 0.0128, bounds=[-inf:inf], expr='delr_cu1'>), ('sigma2_pow2eqewd23', <Parameter 'sigma2_pow2eqewd23', value=0.00899999999743938 +/- 0.00122, bounds=[-inf:inf], expr='sigma2_cu1'>), ('third_pow2eqewd23', <Parameter 'third_pow2eqewd23', value=0.0 (fixed), bounds=[-inf:inf]>), ('fourth_pow2eqewd23', <Parameter 'fourth_pow2eqewd23', value=0.0 (fixed), bounds=[-inf:inf]>), ('degen_pggt7dxxnn6', <Parameter 'degen_pggt7dxxnn6', value=1 (fixed), bounds=[-inf:inf]>), ('s02_pggt7dxxnn6', <Parameter 's02_pggt7dxxnn6', value=43.60080714165657 +/- 3.34, bounds=[-inf:inf], expr='s02 * n_cucu2'>), ('e0_pggt7dxxnn6', <Parameter 'e0_pggt7dxxnn6', value=5.993656465366165 +/- 0.804, bounds=[-inf:inf], expr='e0'>), ('ei_pggt7dxxnn6', <Parameter 'ei_pggt7dxxnn6', value=0.0 (fixed), bounds=[-inf:inf]>), ('deltar_pggt7dxxnn6', <Parameter 'deltar_pggt7dxxnn6', value=-0.07040999722602559 +/- 0.0222, bounds=[-inf:inf], expr='delr_cu2'>), ('sigma2_pggt7dxxnn6', <Parameter 'sigma2_pggt7dxxnn6', value=0.0025706243934819953 +/- 0.00409, bounds=[-inf:inf], expr='sigma2_cu2'>), ('third_pggt7dxxnn6', <Parameter 'third_pggt7dxxnn6', value=0.0 (fixed), bounds=[-inf:inf]>), ('fourth_pggt7dxxnn6', <Parameter 'fourth_pggt7dxxnn6', value=0.0 (fixed), bounds=[-inf:inf]>)])
