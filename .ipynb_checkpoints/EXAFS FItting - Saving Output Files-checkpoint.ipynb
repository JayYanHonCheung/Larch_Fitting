# %%
from larch.xafs import feffit, feffit_dataset, feffit_transform, feffit_report
from larch.xafs import pre_edge, autobk, xftf, xftr, ff2chi, feffpath
from larch.fitting import  param_group, param
from larch.io import h5group, read_ascii, read_athena, read_xdi, read_specfile, extract_athenagroup

import h5py
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# [root] WARNING : Larchs apps and shell are not supported due to missing dependencies: cannot import name 'LarchWxApp' from 'larch.wxlib' (D:\Python\Anaconda3\envs\xraylarch\lib\site-packages\larch\wxlib\__init__.py)

# %%
standard_path = "..\\Data\\Larch_Fitting\\time_series\\12s_70C_Art_2000ms_1374.dat"

# %%
""" 1. Reading Data """

# Initialisation
data = read_ascii(standard_path, labels="energy mu")
data.groupname = "data_1058"

# Pre-processing - EXAFS fittings only need a valid k space
autobk(data, rbkg=1.18) # Need to have option to suppress normalisation in case loaded spectra is already normed
xftf(data, kmin=3.0, kmax=10, dk=1.0, window="hanning", kweight=2.00)
xftr(data, rmin=1.0, rmax=4.0, dr=1.0, window="hanning")

# %%
""" Misc: Plotting """
energy = data.energy
mu = data.mu
norm = data.norm
chi = data.chi
k = data.k
chir_mag = data.chir_mag
r = data.r

fig, ax = plt.subplots(1, 3, figsize=(15, 5))

ax[0].plot(energy, norm)
ax[1].plot(k, chi)
ax[2].plot(r, chir_mag)

# %%
""" 2. Set up feffit. """

# Create feffit Parameter Group to hold fit parameters
_feffit_params = param_group(n_cucu=param(1.0, vary=True),
                             n_cuo=param(1.0, vary=True),
                             s02=param(0.87348, min=0, vary=False),
                             e0=param(0.1, min=-10, max=10, vary=True),
                             delr_Cu=param(0.001, min=-0.5, max=0.5, vary=True),
                             delr_O=param(0.001, min=-0.5, max=0.5, vary=True),
                             sigma2_Cu=param(0.008, min=0.0, max=0.009, vary=True),
                             sigma2_O=param(0.008, min=0.0, max=0.009, vary=True))


# Define Fourier transform and fitting space
# Actual FT parameters for EXAFS fitting
_feffit_trans = feffit_transform(kmin=3.000, kmax=10.000, dk=1.0000, kw=2,
                                 window="hanning", fitspace='r', rmin=1.000, rmax=4.000)

# Make sure a dictionary for Feff Paths exists
try:
    npaths = len(_paths.keys())
except:
    _paths = {}
    
_paths['Cu256'] = feffpath("C:/Users/user/larch/feff/Cu1_K_Copper_cif11145/feff0001.dat",
                  label='Cu256', degen=1,
                  s02='n_cucu * s02',     e0='e0',
                  deltar='delr_Cu', sigma2='sigma2_Cu')

_paths['O195'] = feffpath('C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat',
                  label='O195', degen=1,
                  s02='n_cuo * s02',     e0='e0',
                  deltar='delr_O', sigma2='sigma2_O')

# Make dict of paths, sum them using a group of parameters
_ff2chi_paths  = {'Cu256': _paths['Cu256'], "O195": _paths["O195"]}
# if len(_ff2chi_paths) > 0:
#     _pathsum = ff2chi(_ff2chi_paths, paramgroup=_feffit_params)
    
# Build feffit dataset, run feffit
_feffit_dataset = feffit_dataset(data=data, transform=_feffit_trans, paths=_ff2chi_paths)
_feffit_result = feffit(_feffit_params, [_feffit_dataset]) # _feffit_dataset can be a list***

# # Insert _feffit_result into self.feffit_history
# if not hasattr(data, 'feffit_history'): 
#     data.feffit_history = []    
# _feffit_result.label = 'Fit %i' % (1+len(data.feffit_history))
# data.feffit_history.insert(0, _feffit_result)

# %%
""" Misc: Plotting fitted results"""

data_r = _feffit_dataset.data.r
data_chir_mag = _feffit_dataset.data.chir_mag

fit_r = _feffit_result.datasets[0].model.r
fit_chir_mag = _feffit_result.datasets[0].model.chir_mag

a = _feffit_result.datasets[0].paths["Cu256"].r
b = _feffit_result.datasets[0].paths["Cu256"].chir_mag

c = _feffit_result.datasets[0].paths["O195"].r
d = _feffit_result.datasets[0].paths["O195"].chir_mag

fig = plt.figure(figsize=(12, 6))
plt.plot(fit_r, fit_chir_mag, color="r", label="fit")
plt.plot(data_r, data_chir_mag, lw=0, marker='o', markersize=3, fillstyle='none', color="k", label="Raw Data")
plt.plot(a, b, label="Cu-Cu")
plt.plot(c, d, label="Cu-O")
plt.axhline(0, color="k", linestyle=":")
plt.legend()

# %%
""" Misc: Print fitted results. """
print(feffit_report(_feffit_result))
# Out:
# =================== FEFFIT RESULTS ====================
# [[Statistics]]
#    nvarys, npts       =  7, 196
#    n_independent      =  14.369
#    chi_square         =  36.8309836
#    reduced chi_square =  4.99808760
#    r-factor           =  0.06141680
#    Akaike info crit   =  27.5250550
#    Bayesian info crit =  32.1805742
#
# [[Data]]
#    fit space          = 'r'
#    r-range            = 1.000, 4.000
#    k-range            = 3.000, 10.000
#    k window, dk       = 'hanning', 1.000
#    paths used in fit  = ['C:/Users/user/larch/feff/Cu1_K_Copper_cif11145/feff0001.dat', 'C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat']
#    k-weight           = 2
#    epsilon_k          = Array(mean=0.00516270, std=0.00688001)
#    epsilon_r          = 0.04599854
#    n_independent      = 14.369
#
# [[Variables]]
#    delr_Cu        =  0.14399389 +/- 0.07485984   (init=  1.0000e-03)
#    delr_O         = -0.04315821 +/- 0.02419253   (init=  1.0000e-03)
#    e0             =  4.92480013 +/- 3.11552675   (init=  0.10000000)
#    n_cucu         =  0.14292412 +/- 0.52973547   (init=  1.00000000)
#    n_cuo          =  3.06551372 +/- 0.69661195   (init=  1.00000000)
#    s02            =  0.87348000 (fixed)
#    sigma2_Cu      =  5.4351e-12 +/- 0.00221092   (init=  0.00800000)
#    sigma2_O       =  0.00794624 +/- 0.00360687   (init=  0.00800000)
#
# [[Correlations]]    (unreported correlations are <  0.100)
#    n_cucu, sigma2_Cu    = -0.957
#    delr_O, e0           =  0.902
#    n_cuo, sigma2_O      =  0.888
#    delr_Cu, sigma2_Cu   = -0.377
#    delr_Cu, n_cucu      =  0.370
#    e0, n_cuo            = -0.332
#    delr_Cu, e0          =  0.234
#    delr_Cu, n_cuo       = -0.203
#    delr_Cu, sigma2_O    = -0.200
#    delr_Cu, delr_O      =  0.178
#    e0, sigma2_O         = -0.170
#    delr_O, n_cuo        = -0.121
#
# [[Paths]]
#  = Path 'Cu256' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Copper_cif11145/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#               Cu      -1.8075, -0.0000, -1.8075  1
#      reff   =  2.55620000
#      degen  =  1.00000000
#      n*s02  =  0.12484136 +/- 0.46271334  := 'n_cucu * s02'
#      e0     =  4.92480013 +/- 3.11552675  := 'e0'
#      r      =  2.70019389 +/- 0.07485984  := 'reff + delr_Cu'
#      deltar =  0.14399389 +/- 0.07485984  := 'delr_Cu'
#      sigma2 =  5.4351e-12 +/- 0.00221092  := 'sigma2_Cu'
#
#  = Path 'O195' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#                O      -1.1474,  1.1389, -1.0854  2
#      reff   =  1.94720000
#      degen  =  1.00000000
#      n*s02  =  2.67766492 +/- 0.60847661  := 'n_cuo * s02'
#      e0     =  4.92480013 +/- 3.11552675  := 'e0'
#      r      =  1.90404179 +/- 0.02419253  := 'reff + delr_O'
#      deltar = -0.04315821 +/- 0.02419253  := 'delr_O'
#      sigma2 =  0.00794624 +/- 0.00360687  := 'sigma2_O'
#
# =======================================================

# %%
""" Misc: Extract fitted parameters. """
_feffit_result
# Out:
# <Group feffit results>

# %%
import pickle
params = _feffit_result.params
ser = pickle.dumps(params)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-478f2d85dc2f> in <module>
#       1 import pickle
#       2 params = _feffit_result.params
# ----> 3 ser = pickle.dumps(params)
#
# D:\Python\Anaconda3\envs\xraylarch\lib\site-packages\lmfit\parameter.py in __reduce__(self)
#     156         # find the symbols from _asteval.symtable, that need to be remembered.
#     157         sym_unique = self._asteval.user_defined_symbols()
# --> 158         unique_symbols = {key: deepcopy(self._asteval.symtable[key])
#     159                           for key in sym_unique}
#     160
#
# D:\Python\Anaconda3\envs\xraylarch\lib\site-packages\lmfit\parameter.py in <dictcomp>(.0)
#     156         # find the symbols from _asteval.symtable, that need to be remembered.
#     157         sym_unique = self._asteval.user_defined_symbols()
# --> 158         unique_symbols = {key: deepcopy(self._asteval.symtable[key])
#     159                           for key in sym_unique}
#     160
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     267     if state is not None:
#     268         if deep:
# --> 269             state = deepcopy(state, memo)
#     270         if hasattr(y, '__setstate__'):
#     271             y.__setstate__(state)
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     227     memo[id(x)] = y
#     228     for key, value in x.items():
# --> 229         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     230     return y
#     231 d[dict] = _deepcopy_dict
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     267     if state is not None:
#     268         if deep:
# --> 269             state = deepcopy(state, memo)
#     270         if hasattr(y, '__setstate__'):
#     271             y.__setstate__(state)
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     227     memo[id(x)] = y
#     228     for key, value in x.items():
# --> 229         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     230     return y
#     231 d[dict] = _deepcopy_dict
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     267     if state is not None:
#     268         if deep:
# --> 269             state = deepcopy(state, memo)
#     270         if hasattr(y, '__setstate__'):
#     271             y.__setstate__(state)
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     227     memo[id(x)] = y
#     228     for key, value in x.items():
# --> 229         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     230     return y
#     231 d[dict] = _deepcopy_dict
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     267     if state is not None:
#     268         if deep:
# --> 269             state = deepcopy(state, memo)
#     270         if hasattr(y, '__setstate__'):
#     271             y.__setstate__(state)
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     227     memo[id(x)] = y
#     228     for key, value in x.items():
# --> 229         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     230     return y
#     231 d[dict] = _deepcopy_dict
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     227     memo[id(x)] = y
#     228     for key, value in x.items():
# --> 229         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     230     return y
#     231 d[dict] = _deepcopy_dict
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     267     if state is not None:
#     268         if deep:
# --> 269             state = deepcopy(state, memo)
#     270         if hasattr(y, '__setstate__'):
#     271             y.__setstate__(state)
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     227     memo[id(x)] = y
#     228     for key, value in x.items():
# --> 229         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     230     return y
#     231 d[dict] = _deepcopy_dict
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     227     memo[id(x)] = y
#     228     for key, value in x.items():
# --> 229         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     230     return y
#     231 d[dict] = _deepcopy_dict
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     267     if state is not None:
#     268         if deep:
# --> 269             state = deepcopy(state, memo)
#     270         if hasattr(y, '__setstate__'):
#     271             y.__setstate__(state)
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     227     memo[id(x)] = y
#     228     for key, value in x.items():
# --> 229         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     230     return y
#     231 d[dict] = _deepcopy_dict
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     159                     reductor = getattr(x, "__reduce_ex__", None)
#     160                     if reductor is not None:
# --> 161                         rv = reductor(4)
#     162                     else:
#     163                         reductor = getattr(x, "__reduce__", None)
#
# TypeError: cannot pickle '_thread.lock' object

# %%
params["delr_Cu"].__dict__.keys()
# Out:
# dict_keys(['name', 'user_data', 'init_value', 'min', 'max', 'brute_step', 'vary', '_expr', '_expr_ast', '_expr_eval', '_expr_deps', '_delay_asteval', 'stderr', 'correl', 'from_internal', '_val'])

# %%
print(params["delr_Cu"]._val)
# Out:
# 0.14399389408893426

# %%
ser2 = pickle.dumps(params["delr_Cu"])

# %%
ser3 = pickle.dumps(dict(params))

# %%
fitter = _feffit_result.fitter
fitter.__dict__
# Out:
# {'userfcn': <function larch.xafs.feffit.feffit.<locals>._resid(params, datasets=None, pargroup=None, **kwargs)>,
#  'userargs': [],
#  'userkws': {'datasets': [<FeffitDataSet Group: 0x294fb3bf2e0>],
#   'pargroup': <Group 0x294fb3bf550>},
#  'kws': {},
#  'iter_cb': None,
#  'calc_covar': True,
#  'scale_covar': True,
#  'max_nfev': 16000,
#  'nfev': 0,
#  'nfree': 0,
#  'ndata': 0,
#  'ier': 0,
#  '_abort': False,
#  'success': True,
#  'errorbars': False,
#  'message': None,
#  'lmdif_message': None,
#  'chisqr': None,
#  'redchi': None,
#  'covar': None,
#  'residual': None,
#  'reduce_fcn': <function lmfit.minimizer.reduce_chisquare(r)>,
#  'params': Parameters([('delr_Cu', <Parameter 'delr_Cu', value=0.14399389408893426 +/- 0.0749, bounds=[-0.5:0.5]>), ('delr_O', <Parameter 'delr_O', value=-0.04315821077315296 +/- 0.0242, bounds=[-0.5:0.5]>), ('e0', <Parameter 'e0', value=4.924800132875431 +/- 3.12, bounds=[-10:10]>), ('n_cucu', <Parameter 'n_cucu', value=0.14292412115547637 +/- 0.53, bounds=[-inf:inf]>), ('n_cuo', <Parameter 'n_cuo', value=3.0655137179682086 +/- 0.697, bounds=[-inf:inf]>), ('s02', <Parameter 's02', value=0.87348 (fixed), bounds=[0:inf]>), ('sigma2_Cu', <Parameter 'sigma2_Cu', value=5.435097372163966e-12 +/- 0.00221, bounds=[0.0:0.009]>), ('sigma2_O', <Parameter 'sigma2_O', value=0.007946240311655759 +/- 0.00361, bounds=[0.0:0.009]>), ('degen_pxstpuoxe6p', <Parameter 'degen_pxstpuoxe6p', value=1 (fixed), bounds=[-inf:inf]>), ('s02_pxstpuoxe6p', <Parameter 's02_pxstpuoxe6p', value=0.1248413613468855, bounds=[-inf:inf], expr='n_cucu * s02'>), ('e0_pxstpuoxe6p', <Parameter 'e0_pxstpuoxe6p', value=4.924800132875431, bounds=[-inf:inf], expr='e0'>), ('ei_pxstpuoxe6p', <Parameter 'ei_pxstpuoxe6p', value=0.0 (fixed), bounds=[-inf:inf]>), ('deltar_pxstpuoxe6p', <Parameter 'deltar_pxstpuoxe6p', value=0.14399389408893426, bounds=[-inf:inf], expr='delr_Cu'>), ('sigma2_pxstpuoxe6p', <Parameter 'sigma2_pxstpuoxe6p', value=5.435097372163966e-12, bounds=[-inf:inf], expr='sigma2_Cu'>), ('third_pxstpuoxe6p', <Parameter 'third_pxstpuoxe6p', value=0.0 (fixed), bounds=[-inf:inf]>), ('fourth_pxstpuoxe6p', <Parameter 'fourth_pxstpuoxe6p', value=0.0 (fixed), bounds=[-inf:inf]>), ('degen_p2uhikgpj3v', <Parameter 'degen_p2uhikgpj3v', value=1 (fixed), bounds=[-inf:inf]>), ('s02_p2uhikgpj3v', <Parameter 's02_p2uhikgpj3v', value=2.677664922370871, bounds=[-inf:inf], expr='n_cuo * s02'>), ('e0_p2uhikgpj3v', <Parameter 'e0_p2uhikgpj3v', value=4.924800132875431, bounds=[-inf:inf], expr='e0'>), ('ei_p2uhikgpj3v', <Parameter 'ei_p2uhikgpj3v', value=0.0 (fixed), bounds=[-inf:inf]>), ('deltar_p2uhikgpj3v', <Parameter 'deltar_p2uhikgpj3v', value=-0.04315821077315296, bounds=[-inf:inf], expr='delr_O'>), ('sigma2_p2uhikgpj3v', <Parameter 'sigma2_p2uhikgpj3v', value=0.007946240311655759, bounds=[-inf:inf], expr='sigma2_O'>), ('third_p2uhikgpj3v', <Parameter 'third_p2uhikgpj3v', value=0.0 (fixed), bounds=[-inf:inf]>), ('fourth_p2uhikgpj3v', <Parameter 'fourth_p2uhikgpj3v', value=0.0 (fixed), bounds=[-inf:inf]>)]),
#  'col_deriv': False,
#  'jacfcn': None,
#  'nan_policy': 'raise',
#  'result': <lmfit.minimizer.MinimizerResult at 0x294fb3ad190>}

# %%
_feffit_result.fit_details.__dict__.keys()
# Out:
# dict_keys(['params', 'var_names', 'init_vals', 'nfev', 'call_kws', 'errorbars', 'aborted', 'nvarys', 'init_values', 'method', 'last_internal_values', 'residual', 'chisqr', 'ndata', 'nfree', 'redchi', 'aic', 'bic', 'ier', 'lmdif_message', 'success', 'message', 'covar'])

# %%
pickle.dumps(_feffit_result.fitter)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-a2055b86983c> in <module>
# ----> 1 pickle.dumps(_feffit_result.fitter.params)
#
# D:\Python\Anaconda3\envs\xraylarch\lib\site-packages\lmfit\parameter.py in __reduce__(self)
#     156         # find the symbols from _asteval.symtable, that need to be remembered.
#     157         sym_unique = self._asteval.user_defined_symbols()
# --> 158         unique_symbols = {key: deepcopy(self._asteval.symtable[key])
#     159                           for key in sym_unique}
#     160
#
# D:\Python\Anaconda3\envs\xraylarch\lib\site-packages\lmfit\parameter.py in <dictcomp>(.0)
#     156         # find the symbols from _asteval.symtable, that need to be remembered.
#     157         sym_unique = self._asteval.user_defined_symbols()
# --> 158         unique_symbols = {key: deepcopy(self._asteval.symtable[key])
#     159                           for key in sym_unique}
#     160
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     267     if state is not None:
#     268         if deep:
# --> 269             state = deepcopy(state, memo)
#     270         if hasattr(y, '__setstate__'):
#     271             y.__setstate__(state)
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     227     memo[id(x)] = y
#     228     for key, value in x.items():
# --> 229         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     230     return y
#     231 d[dict] = _deepcopy_dict
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     267     if state is not None:
#     268         if deep:
# --> 269             state = deepcopy(state, memo)
#     270         if hasattr(y, '__setstate__'):
#     271             y.__setstate__(state)
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     227     memo[id(x)] = y
#     228     for key, value in x.items():
# --> 229         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     230     return y
#     231 d[dict] = _deepcopy_dict
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     267     if state is not None:
#     268         if deep:
# --> 269             state = deepcopy(state, memo)
#     270         if hasattr(y, '__setstate__'):
#     271             y.__setstate__(state)
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     227     memo[id(x)] = y
#     228     for key, value in x.items():
# --> 229         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     230     return y
#     231 d[dict] = _deepcopy_dict
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     267     if state is not None:
#     268         if deep:
# --> 269             state = deepcopy(state, memo)
#     270         if hasattr(y, '__setstate__'):
#     271             y.__setstate__(state)
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     227     memo[id(x)] = y
#     228     for key, value in x.items():
# --> 229         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     230     return y
#     231 d[dict] = _deepcopy_dict
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     227     memo[id(x)] = y
#     228     for key, value in x.items():
# --> 229         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     230     return y
#     231 d[dict] = _deepcopy_dict
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     267     if state is not None:
#     268         if deep:
# --> 269             state = deepcopy(state, memo)
#     270         if hasattr(y, '__setstate__'):
#     271             y.__setstate__(state)
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     227     memo[id(x)] = y
#     228     for key, value in x.items():
# --> 229         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     230     return y
#     231 d[dict] = _deepcopy_dict
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     227     memo[id(x)] = y
#     228     for key, value in x.items():
# --> 229         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     230     return y
#     231 d[dict] = _deepcopy_dict
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     267     if state is not None:
#     268         if deep:
# --> 269             state = deepcopy(state, memo)
#     270         if hasattr(y, '__setstate__'):
#     271             y.__setstate__(state)
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     227     memo[id(x)] = y
#     228     for key, value in x.items():
# --> 229         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     230     return y
#     231 d[dict] = _deepcopy_dict
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     159                     reductor = getattr(x, "__reduce_ex__", None)
#     160                     if reductor is not None:
# --> 161                         rv = reductor(4)
#     162                     else:
#     163                         reductor = getattr(x, "__reduce__", None)
#
# TypeError: cannot pickle '_thread.lock' object

# %%
details.params = None
ser4 = pickle.dumps(details)

# %%
ser = pickle.dumps(dict(_feffit_result.params))
_feffit_result.fit_details.params = dict(_feffit_result.fit_details.params)
ser1 = pickle.dumps(_feffit_result.fit_details)

# %%
_feffit_result.fitter.params = dict(_feffit_result.fitter.params)
_feffit_result.fitter.result.params = dict(_feffit_result.fitter.params)
_feffit_result.fitter.userfcn = None
# _feffit_result.fitter.userkws["datasets"][0]
ser6 = pickle.dumps(_feffit_result.fitter.userkws["datasets"][0])
# Out:
# <FeffitDataSet Group: 0x294fb3bf2e0>

# %%
ser6 = pickle.dumps(_feffit_result.fitter.userkws["datasets"][0].prepare_fit)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-137-a7ccce4b1b23> in <module>
# ----> 1 ser6 = pickle.dumps(_feffit_result.fitter.userkws["datasets"][0].prepare_fit)
#
# D:\Python\Anaconda3\envs\xraylarch\lib\site-packages\lmfit\parameter.py in __reduce__(self)
#     156         # find the symbols from _asteval.symtable, that need to be remembered.
#     157         sym_unique = self._asteval.user_defined_symbols()
# --> 158         unique_symbols = {key: deepcopy(self._asteval.symtable[key])
#     159                           for key in sym_unique}
#     160
#
# D:\Python\Anaconda3\envs\xraylarch\lib\site-packages\lmfit\parameter.py in <dictcomp>(.0)
#     156         # find the symbols from _asteval.symtable, that need to be remembered.
#     157         sym_unique = self._asteval.user_defined_symbols()
# --> 158         unique_symbols = {key: deepcopy(self._asteval.symtable[key])
#     159                           for key in sym_unique}
#     160
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     267     if state is not None:
#     268         if deep:
# --> 269             state = deepcopy(state, memo)
#     270         if hasattr(y, '__setstate__'):
#     271             y.__setstate__(state)
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     227     memo[id(x)] = y
#     228     for key, value in x.items():
# --> 229         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     230     return y
#     231 d[dict] = _deepcopy_dict
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     267     if state is not None:
#     268         if deep:
# --> 269             state = deepcopy(state, memo)
#     270         if hasattr(y, '__setstate__'):
#     271             y.__setstate__(state)
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     227     memo[id(x)] = y
#     228     for key, value in x.items():
# --> 229         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     230     return y
#     231 d[dict] = _deepcopy_dict
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     267     if state is not None:
#     268         if deep:
# --> 269             state = deepcopy(state, memo)
#     270         if hasattr(y, '__setstate__'):
#     271             y.__setstate__(state)
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     227     memo[id(x)] = y
#     228     for key, value in x.items():
# --> 229         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     230     return y
#     231 d[dict] = _deepcopy_dict
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     267     if state is not None:
#     268         if deep:
# --> 269             state = deepcopy(state, memo)
#     270         if hasattr(y, '__setstate__'):
#     271             y.__setstate__(state)
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     227     memo[id(x)] = y
#     228     for key, value in x.items():
# --> 229         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     230     return y
#     231 d[dict] = _deepcopy_dict
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     227     memo[id(x)] = y
#     228     for key, value in x.items():
# --> 229         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     230     return y
#     231 d[dict] = _deepcopy_dict
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     267     if state is not None:
#     268         if deep:
# --> 269             state = deepcopy(state, memo)
#     270         if hasattr(y, '__setstate__'):
#     271             y.__setstate__(state)
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     227     memo[id(x)] = y
#     228     for key, value in x.items():
# --> 229         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     230     return y
#     231 d[dict] = _deepcopy_dict
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     227     memo[id(x)] = y
#     228     for key, value in x.items():
# --> 229         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     230     return y
#     231 d[dict] = _deepcopy_dict
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     267     if state is not None:
#     268         if deep:
# --> 269             state = deepcopy(state, memo)
#     270         if hasattr(y, '__setstate__'):
#     271             y.__setstate__(state)
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     227     memo[id(x)] = y
#     228     for key, value in x.items():
# --> 229         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     230     return y
#     231 d[dict] = _deepcopy_dict
#
# D:\Python\Anaconda3\envs\xraylarch\lib\copy.py in deepcopy(x, memo, _nil)
#     159                     reductor = getattr(x, "__reduce_ex__", None)
#     160                     if reductor is not None:
# --> 161                         rv = reductor(4)
#     162                     else:
#     163                         reductor = getattr(x, "__reduce__", None)
#
# TypeError: cannot pickle '_thread.lock' object

# %%
params = _feffit_result.params
params
# Out:
# Parameters([('delr_Cu', <Parameter 'delr_Cu', value=0.14399389408893426 +/- 0.0749, bounds=[-0.5:0.5]>), ('delr_O', <Parameter 'delr_O', value=-0.04315821077315296 +/- 0.0242, bounds=[-0.5:0.5]>), ('e0', <Parameter 'e0', value=4.924800132875431 +/- 3.12, bounds=[-10:10]>), ('n_cucu', <Parameter 'n_cucu', value=0.14292412115547637 +/- 0.53, bounds=[-inf:inf]>), ('n_cuo', <Parameter 'n_cuo', value=3.0655137179682086 +/- 0.697, bounds=[-inf:inf]>), ('s02', <Parameter 's02', value=0.87348 (fixed), bounds=[0:inf]>), ('sigma2_Cu', <Parameter 'sigma2_Cu', value=5.435097372163966e-12 +/- 0.00221, bounds=[0.0:0.009]>), ('sigma2_O', <Parameter 'sigma2_O', value=0.007946240311655759 +/- 0.00361, bounds=[0.0:0.009]>), ('degen_pxstpuoxe6p', <Parameter 'degen_pxstpuoxe6p', value=1 (fixed), bounds=[-inf:inf]>), ('s02_pxstpuoxe6p', <Parameter 's02_pxstpuoxe6p', value=0.1248413613468855 +/- 0.463, bounds=[-inf:inf], expr='n_cucu * s02'>), ('e0_pxstpuoxe6p', <Parameter 'e0_pxstpuoxe6p', value=4.924800132875431 +/- 3.12, bounds=[-inf:inf], expr='e0'>), ('ei_pxstpuoxe6p', <Parameter 'ei_pxstpuoxe6p', value=0.0 (fixed), bounds=[-inf:inf]>), ('deltar_pxstpuoxe6p', <Parameter 'deltar_pxstpuoxe6p', value=0.14399389408893426 +/- 0.0749, bounds=[-inf:inf], expr='delr_Cu'>), ('sigma2_pxstpuoxe6p', <Parameter 'sigma2_pxstpuoxe6p', value=5.435097372163966e-12 +/- 0.00221, bounds=[-inf:inf], expr='sigma2_Cu'>), ('third_pxstpuoxe6p', <Parameter 'third_pxstpuoxe6p', value=0.0 (fixed), bounds=[-inf:inf]>), ('fourth_pxstpuoxe6p', <Parameter 'fourth_pxstpuoxe6p', value=0.0 (fixed), bounds=[-inf:inf]>), ('degen_p2uhikgpj3v', <Parameter 'degen_p2uhikgpj3v', value=1 (fixed), bounds=[-inf:inf]>), ('s02_p2uhikgpj3v', <Parameter 's02_p2uhikgpj3v', value=2.677664922370871 +/- 0.608, bounds=[-inf:inf], expr='n_cuo * s02'>), ('e0_p2uhikgpj3v', <Parameter 'e0_p2uhikgpj3v', value=4.924800132875431 +/- 3.12, bounds=[-inf:inf], expr='e0'>), ('ei_p2uhikgpj3v', <Parameter 'ei_p2uhikgpj3v', value=0.0 (fixed), bounds=[-inf:inf]>), ('deltar_p2uhikgpj3v', <Parameter 'deltar_p2uhikgpj3v', value=-0.04315821077315296 +/- 0.0242, bounds=[-inf:inf], expr='delr_O'>), ('sigma2_p2uhikgpj3v', <Parameter 'sigma2_p2uhikgpj3v', value=0.007946240193247552 +/- 0.00361, bounds=[-inf:inf], expr='sigma2_O'>), ('third_p2uhikgpj3v', <Parameter 'third_p2uhikgpj3v', value=0.0 (fixed), bounds=[-inf:inf]>), ('fourth_p2uhikgpj3v', <Parameter 'fourth_p2uhikgpj3v', value=0.0 (fixed), bounds=[-inf:inf]>)])

# %%
result = copy.deepcopy(_feffit_result)

result

result.fitter = None
result.fit_details = None
result.params = dict(result.params)

# Open a file and use dump()
with open('test_pickle_output.pkl', 'wb') as file:
      
    # A new file will be created
    pickle.dump(result, file)

# %%
# Open the file in binary mode
with open('test_pickle_output.pkl', 'rb') as file:
      
    # Call load method to deserialze
    myvar = pickle.load(file)
# Out:
# <Group 0x294fb6fe610>

# %%
myvar
# Out:
# <Group 0x294fb6fe610>

# %%
"""
Notes on _feffit_result:

As usual to larch, it is organised into a group.

Notes on: fitter, fit_details, params
They are lmfit objects, which cause issue when pickling.

Notes on params:
The same variables/data seems to appear in multiple locations
1. _feffit_result.fitter.params
2. _feffit_result.fit_details.params
3. _feffit_result.params

"params" contains an attribute "_asteval" which causes a ".thread_lock" error pickling.
This is workaround by re-assigning param as dict(param), which should retain all the parameters while removing the _asteval.
No clue what _asteval actually does yet.

Notes on fit_details:
1. _feffit_result.fit_details
2. _feffit_result.fitter.result

Notes on fitter:

"fitter" contains a "userfcn" attribute which is a local function and causes "local function" error when pickling.
It is a "residual function" (no idea what it is)

"""
