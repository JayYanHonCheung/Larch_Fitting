# %%
from larch.xafs.feffrunner import feff6l, feff8l, feffrunner
from larch.xrd import cif2feff
from larch.xrd import CifStructure, get_amscifdb, find_cifs, get_cif

import os

""" As of January 2022, this part is not in the xraylarch documentation

A crude adaptation from larch.wxlib.cif_browser.py 
(https://github.com/xraypy/xraylarch/blob/master/larch/wxlib/cif_browser.py)
An equivalent to the function in CIF browser in the XAS Viewer

It generates a feff input file (.inp) from a Crystallographic Information File (.cif), 
then compute scattering path files (.dat) by feff8 (or feff6) for EXAFS fitting

WIP: Some of this needs to be packaged into a .py file.

"""
# Out:
# [root] WARNING : Larchs apps and shell are not supported due to missing dependencies: cannot import name 'LarchWxApp' from 'larch.wxlib' (D:\Python\Anaconda3\envs\xraylarch\lib\site-packages\larch\wxlib\__init__.py)
# ' As of January 2022, this part is not in the xraylarch documentation\n\nA crude adaptation from larch.wxlib.cif_browser.py \n(https://github.com/xraypy/xraylarch/blob/master/larch/wxlib/cif_browser.py)\nAn equivalent to the function in CIF browser in the XAS Viewer\n\nIt generates a feff input file (.inp) from a Crystallographic Information File (.cif), \nthen compute scattering path files (.dat) by feff8 (or feff6) for EXAFS fitting\n\nWIP: Some of this needs to be packaged into a .py file.\n\n'

# %%
# Define the cif file path and feff file path (where the output files will be saved)
cif_path = "data\\demo\\cif\\9008468_Wyckoff_1963_Cu_ccp_Fm3m.cif"
feff_path = "data\\demo\\cif2feff\\"

# %%
"""
Parameters for feff computation:

A series of parameters are required to compute the scattering paths.

1. String: Absorber atom
2. String: Edge
3. Int:    Cluster size (Angstrom)
4. Int:    Absorber site
5. Bool:   feff version8 (if False, uses feff6 instead)

"""
catom = "Cu"
edge = "K"
csize = 6
asite = 1
version8 = True

# %%
# Create output directory
cif_name = os.path.basename(cif_path)[:-4]
fname = f"{catom}{asite}_{edge}_{cif_name}"
feff_folder = os.path.join(feff_path, fname)

if not os.path.exists(feff_folder):
    os.makedirs(feff_folder)

# %%
# Adapated code from larch to read cif file, generate and run feff input (.inp) file
ini = get_amscifdb()
cif_id = ini.add_ciffile(cif_path)
cif = get_cif(cif_id)
ciftext = cif.ciftext
fefftext = cif.get_feffinp(catom, edge=edge, cluster_size=csize, absorber_site=asite, version8=version8)

# Save feff input file (.inp)
feffinp_path = os.path.join(feff_folder, "feff_input.inp")
with open(feffinp_path, "w") as output:
    output.write(fefftext)

# %%
# Run feffrunner from larch
feff = feffrunner(feffinp=feffinp_path)
feff.run()
# Out:
#  : ======== running Feff module feff8l_rdinp ========
#  : Feff8L (EXAFS)      release  0.1
#  : Structure from AMSCIFDB, AMS_ID: 9008468
#  : Mineral Name: Copper
#  : Journal: Crystal Structures 1, pp. 7-83 (1963)
#  : Authors: Wyckoff R W G
#  : Title1:   Second edition. Interscience Publishers, New York, New York  Cubic cl
#  : Formula:    Cu
#  : SpaceGroup: Fm-3m
#  : # sites:    1
#  : ======== running Feff module feff8l_pot ========
#  : Calculating potentials ...
#  : free atom potential and density for atom type    0
#  : free atom potential and density for atom type    1
#  : initial state energy
#  : overlapped potential and density for unique potential    0
#  : overlapped potential and density for unique potential    1
#  : muffin tin radii and interstitial parameters
#  : : ipot, Norman radius, Muffin tin radius, Overlap
#  : 0  1.50430E+00  1.45091E+00  1.09393E+00
#  : 1  1.39485E+00  1.35739E+00  1.06881E+00
#  : : mu_old=    -3.733
#  : Done with module 1: potentials.
#  : ======== running Feff module feff8l_xsph ========
#  : Calculating cross-section and phases...
#  : absorption cross section
#  : phase shifts for unique potential    0
#  : phase shifts for unique potential    1
#  : Done with module 2: cross-section and phases...
#  : ======== running Feff module feff8l_pathfinder ========
#  : Preparing plane wave scattering amplitudes...
#  : Searching for paths...
#  : WARNING:  rmax > distance to most distant atom.
#  : Some paths may be missing.
#  : rmax, ratx   6.00000E+00  0.00000E+00
#  : Rmax  6.0000  keep and heap limits   0.0000000   0.0000000
#  : Preparing neighbor table
#  : nfound  heapsize  maxheap  maxscatt   reff
#  : 1000      228      274      4      5.2993
#  : Paths found     1926   (maxheap, maxscatt     274   4)
#  : Eliminating path degeneracies...
#  : Plane wave chi amplitude filter   2.50%
#  : Unique paths     20,  total paths     678
#  : Done with module 4: pathfinder.
#  : ======== running Feff module feff8l_genfmt ========
#  : Calculating EXAFS parameters...
#  : Curved wave chi amplitude ratio   4.00%
#  : Discard feff.dat for paths with cw ratio <   2.67%
#  : path  cw ratio     deg    nleg  reff
#  : 1   100.000    12.000     2   2.5562
#  : 2    22.988     6.000     2   3.6150
#  : 3    12.267    48.000     3   3.8342
#  : 4     9.355    48.000     3   4.3636
#  : 5    55.789    24.000     2   4.4274
#  : 6    11.745    48.000     3   4.7699
#  : 7    25.252    96.000     3   4.7699
#  : 8    19.153    12.000     2   5.1123
#  : 9     9.595    12.000     3   5.1123
#  : 10    44.461    24.000     3   5.1123
#  : 11     9.693    12.000     4   5.1123
#  : 12     4.444    12.000     4   5.1123
#  : 13     2.042    48.000     4   5.1123 neglected
#  : 14    32.296    12.000     4   5.1123
#  : 15     2.764    48.000     4   5.1123
#  : 16     4.602    48.000     3   5.2993
#  : 17    28.256    24.000     2   5.7158
#  : 18     9.799    48.000     3   5.9434
#  : 19     7.728    48.000     3   5.9434
#  : 20     8.420    48.000     3   5.9434
#  : 19 paths kept,   20 examined.
#  : Done with module 5: F_eff.
#  : Note: The following floating-point exceptions are signalling: IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
#  : ======== running Feff module feff8l_ff2x ========
#  : Calculating chi...
#  : feffdt, feff.pad to feff.dat conversion: Feff8L (EXAFS)      release  0.1
#  : Structure from AMSCIFDB, AMS_ID: 9008468       Feff8L (EXAFS)       0.1
#  : Mineral Name: Copper
#  : Journal: Crystal Structures 1, pp. 7-83 (1963)
#  : Authors: Wyckoff R W G
#  : Title1:   Second edition. Interscience Publishers, New York, New York  Cubic cl
#  : Formula:    Cu
#  : SpaceGroup: Fm-3m
#  : # sites:    1
#  : POT  Non-SCF, core-hole, AFOLP (folp(0)= 1.150)
#  : Abs   Z=29 Rmt= 1.451 Rnm= 1.504 K  shell
#  : Pot 1 Z=29 Rmt= 1.357 Rnm= 1.395
#  : Gam_ch=1.729E+00 H-L exch
#  : Mu=-3.733E+00 kf=1.821E+00 Vint=-1.637E+01 Rs_int= 1.992
#  : PATH  Rmax= 6.000,  Keep_limit= 0.00, Heap_limit 0.00  Pwcrit= 2.50%
#  : 19 paths to process
#  : path     filename
#  : 1     feff0001.dat
#  : 2     feff0002.dat
#  : 3     feff0003.dat
#  : 4     feff0004.dat
#  : 5     feff0005.dat
#  : 6     feff0006.dat
#  : 7     feff0007.dat
#  : 8     feff0008.dat
#  : 9     feff0009.dat
#  : 10     feff0010.dat
#  : 11     feff0011.dat
#  : 12     feff0012.dat
#  : 13     feff0014.dat
#  : 14     feff0015.dat
#  : 15     feff0016.dat
#  : 16     feff0017.dat
#  : 17     feff0018.dat
#  : 18     feff0019.dat
#  : 19     feff0020.dat
#  : Use all paths with cw amplitude ratio   4.00%
#  : S02  1.000  Global sig2  0.00000
#  : Done with module 6: DW + final sum over paths.

# %%
# Clean up unused, intermediate Feff files (taken from larch's "cif_browser.py ")
for fname in os.listdir(feff_folder):
    if (fname.endswith('.json') or fname.endswith('.pad') or
        fname.endswith('.bin') or fname.startswith('log') or
        fname in ('chi.dat', 'xmu.dat', 'misc.dat')):
        os.unlink(os.path.join(feff_folder, fname))

# %%
# Use a custom script to summarise the generated scattering paths
from tools import get_feff_info as finfo

info = finfo.get_path_info(feff_folder)
info
# Out:
# files.dat found, returning dataframe.
#             file  sig2  amp ratio   deg  nlegs  r effective
# 0   feff0001.dat   0.0    100.000  12.0      2       2.5562
# 1   feff0002.dat   0.0     22.990   6.0      2       3.6150
# 2   feff0003.dat   0.0     12.270  48.0      3       3.8342
# 3   feff0004.dat   0.0      9.355  48.0      3       4.3636
# 4   feff0005.dat   0.0     55.790  24.0      2       4.4274
# 5   feff0006.dat   0.0     11.750  48.0      3       4.7699
# 6   feff0007.dat   0.0     25.250  96.0      3       4.7699
# 7   feff0008.dat   0.0     19.150  12.0      2       5.1123
# 8   feff0009.dat   0.0      9.595  12.0      3       5.1123
# 9   feff0010.dat   0.0     44.460  24.0      3       5.1123
# 10  feff0011.dat   0.0      9.693  12.0      4       5.1123
# 11  feff0012.dat   0.0      4.444  12.0      4       5.1123
# 12  feff0014.dat   0.0     32.300  12.0      4       5.1123
# 13  feff0015.dat   0.0      2.764  48.0      4       5.1123
# 14  feff0016.dat   0.0      4.602  48.0      3       5.2993
# 15  feff0017.dat   0.0     28.260  24.0      2       5.7158
# 16  feff0018.dat   0.0      9.799  48.0      3       5.9434
# 17  feff0019.dat   0.0      7.728  48.0      3       5.9434
# 18  feff0020.dat   0.0      8.420  48.0      3       5.9434
