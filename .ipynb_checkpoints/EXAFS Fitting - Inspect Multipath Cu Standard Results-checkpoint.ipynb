# %%
from tools import io_results
import matplotlib.pyplot as plt

# %%
path = r"cluster_submissions/output/multipath_cu_std/feffit_result.pkl"
result = io_results.load(path)

# %%
fig = plt.figure(figsize=(10, 7))

spectra = result.datasets[0].data
fit = result.datasets[0].model

plt.plot(fit.r, fit.chir_mag)
plt.plot(spectra.r, spectra.chir_mag, lw=0, marker='o', markersize=3, fillstyle='none', color="k", label="Raw Data")
plt.legend()
