# %%
from tools import exafs_param_table as pt

import numpy as np
import pandas as pd
from pandas.api.types import is_string_dtype
from larch.fitting import param_group, param

# %%
feff_folder =  r"data/feffs/Cu1_K_c7_Copper_cif11145"
feff_table = pt.param_table(feff_folder)

# 1. Fitting all paths up to R = 6.5
fit_table = feff_table[feff_table["reff"] < 6.5]

# 2. Assume paths with same reff belongs to the same shell
fit_table = pt.form_shells(fit_table)

# 3. Group sigma2 based on shell
fit_table = pt.groupby_shell(fit_table, ["sigma2"])
# fit_table = pt.independent_params(fit_table, ["sigma2"])

# 4. Separate e0 into 1st shell and the rest
fit_table = pt._1st_shell_e0(fit_table)

# 5. Introduce expansion/contraction factor (alpha)
fit_table["deltar"] = "reff*alpha"
fit_table.insert(11, "alpha", "alpha") # Add a new column for alpha

# Note the subscripts added when grouped by scattering shell
fit_table
# Out:
# files.dat found, returning dataframe.
# files.dat found, returning formula.
#    scatter material  spectra  nlegs    reff  shell  amp ratio  s02     e0  \
# 0                Cu  spectra      2  2.5562      1    100.000  s02  e0_s1
# 1                Cu  spectra      2  3.6150      2     22.990  s02  e0_s2
# 2                Cu  spectra      3  3.8342      3     12.310  s02  e0_s2
# 3                Cu  spectra      3  4.3636      4      9.392  s02  e0_s2
# 4                Cu  spectra      2  4.4274      5     55.800  s02  e0_s2
# 5                Cu  spectra      3  4.7699      6     11.750  s02  e0_s2
# 6                Cu  spectra      3  4.7699      6     25.390  s02  e0_s2
# 7                Cu  spectra      2  5.1123      7     19.160  s02  e0_s2
# 8                Cu  spectra      3  5.1123      7      9.608  s02  e0_s2
# 9                Cu  spectra      3  5.1123      7     44.490  s02  e0_s2
# 10               Cu  spectra      4  5.1123      7      9.657  s02  e0_s2
# 11               Cu  spectra      4  5.1123      7      4.445  s02  e0_s2
# 12               Cu  spectra      4  5.1123      7     32.280  s02  e0_s2
# 13               Cu  spectra      4  5.1123      7      2.750  s02  e0_s2
# 14               Cu  spectra      3  5.2993      8      4.621  s02  e0_s2
# 15               Cu  spectra      2  5.7158      9     28.260  s02  e0_s2
# 16               Cu  spectra      3  5.9434     10      9.809  s02  e0_s2
# 17               Cu  spectra      3  5.9434     10      7.760  s02  e0_s2
# 18               Cu  spectra      3  5.9434     10      8.455  s02  e0_s2
# 19               Cu  spectra      3  6.0479     11      5.691  s02  e0_s2
# 20               Cu  spectra      3  6.0479     11      5.733  s02  e0_s2
# 21               Cu  spectra      4  6.0479     11      5.743  s02  e0_s2
# 22               Cu  spectra      4  6.0479     11      6.140  s02  e0_s2
# 23               Cu  spectra      2  6.2613     12      7.285  s02  e0_s2
# 24               Cu  spectra      3  6.3497     13      6.890  s02  e0_s2
#
#     degen      sigma2      deltar  alpha  \
# 0    12.0   sigma2_s1  reff*alpha  alpha
# 1     6.0   sigma2_s2  reff*alpha  alpha
# 2    48.0   sigma2_s3  reff*alpha  alpha
# 3    48.0   sigma2_s4  reff*alpha  alpha
# 4    24.0   sigma2_s5  reff*alpha  alpha
# 5    48.0   sigma2_s6  reff*alpha  alpha
# 6    96.0   sigma2_s6  reff*alpha  alpha
# 7    12.0   sigma2_s7  reff*alpha  alpha
# 8    12.0   sigma2_s7  reff*alpha  alpha
# 9    24.0   sigma2_s7  reff*alpha  alpha
# 10   12.0   sigma2_s7  reff*alpha  alpha
# 11   12.0   sigma2_s7  reff*alpha  alpha
# 12   12.0   sigma2_s7  reff*alpha  alpha
# 13   48.0   sigma2_s7  reff*alpha  alpha
# 14   48.0   sigma2_s8  reff*alpha  alpha
# 15   24.0   sigma2_s9  reff*alpha  alpha
# 16   48.0  sigma2_s10  reff*alpha  alpha
# 17   48.0  sigma2_s10  reff*alpha  alpha
# 18   48.0  sigma2_s10  reff*alpha  alpha
# 19   96.0  sigma2_s11  reff*alpha  alpha
# 20   96.0  sigma2_s11  reff*alpha  alpha
# 21   96.0  sigma2_s11  reff*alpha  alpha
# 22   96.0  sigma2_s11  reff*alpha  alpha
# 23    8.0  sigma2_s12  reff*alpha  alpha
# 24   96.0  sigma2_s13  reff*alpha  alpha
#
#                                                fpath
# 0   data/feffs/Cu1_K_c7_Copper_cif11145\feff0001.dat
# 1   data/feffs/Cu1_K_c7_Copper_cif11145\feff0002.dat
# 2   data/feffs/Cu1_K_c7_Copper_cif11145\feff0003.dat
# 3   data/feffs/Cu1_K_c7_Copper_cif11145\feff0004.dat
# 4   data/feffs/Cu1_K_c7_Copper_cif11145\feff0005.dat
# 5   data/feffs/Cu1_K_c7_Copper_cif11145\feff0006.dat
# 6   data/feffs/Cu1_K_c7_Copper_cif11145\feff0007.dat
# 7   data/feffs/Cu1_K_c7_Copper_cif11145\feff0008.dat
# 8   data/feffs/Cu1_K_c7_Copper_cif11145\feff0009.dat
# 9   data/feffs/Cu1_K_c7_Copper_cif11145\feff0010.dat
# 10  data/feffs/Cu1_K_c7_Copper_cif11145\feff0011.dat
# 11  data/feffs/Cu1_K_c7_Copper_cif11145\feff0012.dat
# 12  data/feffs/Cu1_K_c7_Copper_cif11145\feff0014.dat
# 13  data/feffs/Cu1_K_c7_Copper_cif11145\feff0015.dat
# 14  data/feffs/Cu1_K_c7_Copper_cif11145\feff0016.dat
# 15  data/feffs/Cu1_K_c7_Copper_cif11145\feff0017.dat
# 16  data/feffs/Cu1_K_c7_Copper_cif11145\feff0018.dat
# 17  data/feffs/Cu1_K_c7_Copper_cif11145\feff0019.dat
# 18  data/feffs/Cu1_K_c7_Copper_cif11145\feff0020.dat
# 19  data/feffs/Cu1_K_c7_Copper_cif11145\feff0021.dat
# 20  data/feffs/Cu1_K_c7_Copper_cif11145\feff0022.dat
# 21  data/feffs/Cu1_K_c7_Copper_cif11145\feff0023.dat
# 22  data/feffs/Cu1_K_c7_Copper_cif11145\feff0024.dat
# 23  data/feffs/Cu1_K_c7_Copper_cif11145\feff0027.dat
# 24  data/feffs/Cu1_K_c7_Copper_cif11145\feff0028.dat

# %%
def constraints_table(param_table):
    """ Helper function to form constraints table for feffit. """
    
    # Column headers
    columns = ["Initial Guess",
               "Lower Bound",
               "Upper Bound"]
    
    # Default values for each corresponding fit parameters
    default_vals = {"s02": [1.0, 0.6, 1.2],
                    "degen": [1.0, -1.0, 16],
                    "sigma2": [0.008, 0.001, 0.015],
                    "e0": [0.1, -25.0, 25.0],
                    "deltar": [0.1, -0.5, 0.5],
                    "alpha": [0.0, -0.1, 0.1]}    
    
    # List of possible fit parameters.
    param_list = ["s02", "degen", "sigma2", "e0", "deltar", "alpha"]
    
    # Get list of fit parameters from param_table
    fit_params = []
    for param in param_list:
        if param in param_table and is_string_dtype(param_table[param]):
            for string in param_table[param].unique():
                if not np.any([symbol in string for symbol in ["*", "/", "-", "+"]]):
                    fit_params.append(string)
    
    # Construct dataframe for fit constraints
    df_cons = pd.DataFrame(columns=columns, index=fit_params)
    
    # Fill in default values
    for i, header in enumerate(df_cons):
        for index in df.index:
            for default_key in default_vals:
                if default_key in index:
                    df_cons[header].loc[index] = default_vals[default_key][i]
    
    return df_cons

# def setup_feffit_params(constraints_table):
#     """ Setup feffit_params for running feffit in larch. """
    
#     # Initialise empty larch param_group
#     feffit_params = param_group()
    
#     # Construct feffit_params using constraints_table dataframe
#     for index in constraints_table.index:
#         ig = constraints_table["Initial Guess"].loc[index]
#         lb = constraints_table["Lower Bound"].loc[index]
#         ub = constraints_table["Upper Bound"].loc[index]
#         setattr(feffit_params, index, param(ig, min=lb, max=ub, vary=True))
        
#     return feffit_params


def setup_feffit_params(table):
    """ Setup feffit_params for running feffit in larch. """
    
    if "Initial Guess" in table.columns:
    
        # Initialise empty larch param_group
        feffit_params = param_group()

        # Construct feffit_params using constraints_table dataframe
        for index in table.index:
            ig = table["Initial Guess"].loc[index]
            lb = table["Lower Bound"].loc[index]
            ub = table["Upper Bound"].loc[index]
            setattr(feffit_params, index, param(ig, min=lb, max=ub, vary=True))

        return feffit_params
    
    elif "scatter material" in table.columns:
        
        # Initialise empty larch param_group
        feffit_params = param_group()

        # Default parameters
        params_dict = {"s02": param(1.0, min=0.6, max=12.0, vary=True),
                       "degen": param(1, min=-1.0, vary=True),
                       "sigma2": param(0.008, min=0.001, max=0.015, vary=True),
                       "e0": param(0.1, min=-25.0, max=25.0, vary=True),
                       "deltar": param(0.1, max=0.5, vary=True),
                       "alpha": param(0.0, min=-0.1, max=0.1, vary=True)} 

        for key in params_dict:
            if key in table:
                if is_string_dtype(table[key]):
                    for i, string in enumerate(table[key].unique()):
                        if not np.any([symbol in string for symbol in ["*", "/", "-", "+"]]):
                            setattr(feffit_params, string, params_dict[key])

        return feffit_params

# %%
feffit_params = setup_feffit_params(df)

# %%
feffit_params
# Out:
# <Param Group 0x1b90f7252b0>

# %%
feffit_params
# Out:
# <Param Group 0x1b90e363d60>

# %%
fit_table
# Out:
#    scatter material  spectra  nlegs    reff  shell  amp ratio  s02     e0  \
# 0                Cu  spectra      2  2.5562      1    100.000  s02  e0_s1
# 1                Cu  spectra      2  3.6150      2     22.990  s02  e0_s2
# 2                Cu  spectra      3  3.8342      3     12.310  s02  e0_s2
# 3                Cu  spectra      3  4.3636      4      9.392  s02  e0_s2
# 4                Cu  spectra      2  4.4274      5     55.800  s02  e0_s2
# 5                Cu  spectra      3  4.7699      6     11.750  s02  e0_s2
# 6                Cu  spectra      3  4.7699      6     25.390  s02  e0_s2
# 7                Cu  spectra      2  5.1123      7     19.160  s02  e0_s2
# 8                Cu  spectra      3  5.1123      7      9.608  s02  e0_s2
# 9                Cu  spectra      3  5.1123      7     44.490  s02  e0_s2
# 10               Cu  spectra      4  5.1123      7      9.657  s02  e0_s2
# 11               Cu  spectra      4  5.1123      7      4.445  s02  e0_s2
# 12               Cu  spectra      4  5.1123      7     32.280  s02  e0_s2
# 13               Cu  spectra      4  5.1123      7      2.750  s02  e0_s2
# 14               Cu  spectra      3  5.2993      8      4.621  s02  e0_s2
# 15               Cu  spectra      2  5.7158      9     28.260  s02  e0_s2
# 16               Cu  spectra      3  5.9434     10      9.809  s02  e0_s2
# 17               Cu  spectra      3  5.9434     10      7.760  s02  e0_s2
# 18               Cu  spectra      3  5.9434     10      8.455  s02  e0_s2
# 19               Cu  spectra      3  6.0479     11      5.691  s02  e0_s2
# 20               Cu  spectra      3  6.0479     11      5.733  s02  e0_s2
# 21               Cu  spectra      4  6.0479     11      5.743  s02  e0_s2
# 22               Cu  spectra      4  6.0479     11      6.140  s02  e0_s2
# 23               Cu  spectra      2  6.2613     12      7.285  s02  e0_s2
# 24               Cu  spectra      3  6.3497     13      6.890  s02  e0_s2
#
#     degen      sigma2      deltar  alpha  \
# 0    12.0   sigma2_s1  reff*alpha  alpha
# 1     6.0   sigma2_s2  reff*alpha  alpha
# 2    48.0   sigma2_s3  reff*alpha  alpha
# 3    48.0   sigma2_s4  reff*alpha  alpha
# 4    24.0   sigma2_s5  reff*alpha  alpha
# 5    48.0   sigma2_s6  reff*alpha  alpha
# 6    96.0   sigma2_s6  reff*alpha  alpha
# 7    12.0   sigma2_s7  reff*alpha  alpha
# 8    12.0   sigma2_s7  reff*alpha  alpha
# 9    24.0   sigma2_s7  reff*alpha  alpha
# 10   12.0   sigma2_s7  reff*alpha  alpha
# 11   12.0   sigma2_s7  reff*alpha  alpha
# 12   12.0   sigma2_s7  reff*alpha  alpha
# 13   48.0   sigma2_s7  reff*alpha  alpha
# 14   48.0   sigma2_s8  reff*alpha  alpha
# 15   24.0   sigma2_s9  reff*alpha  alpha
# 16   48.0  sigma2_s10  reff*alpha  alpha
# 17   48.0  sigma2_s10  reff*alpha  alpha
# 18   48.0  sigma2_s10  reff*alpha  alpha
# 19   96.0  sigma2_s11  reff*alpha  alpha
# 20   96.0  sigma2_s11  reff*alpha  alpha
# 21   96.0  sigma2_s11  reff*alpha  alpha
# 22   96.0  sigma2_s11  reff*alpha  alpha
# 23    8.0  sigma2_s12  reff*alpha  alpha
# 24   96.0  sigma2_s13  reff*alpha  alpha
#
#                                                fpath
# 0   data/feffs/Cu1_K_c7_Copper_cif11145\feff0001.dat
# 1   data/feffs/Cu1_K_c7_Copper_cif11145\feff0002.dat
# 2   data/feffs/Cu1_K_c7_Copper_cif11145\feff0003.dat
# 3   data/feffs/Cu1_K_c7_Copper_cif11145\feff0004.dat
# 4   data/feffs/Cu1_K_c7_Copper_cif11145\feff0005.dat
# 5   data/feffs/Cu1_K_c7_Copper_cif11145\feff0006.dat
# 6   data/feffs/Cu1_K_c7_Copper_cif11145\feff0007.dat
# 7   data/feffs/Cu1_K_c7_Copper_cif11145\feff0008.dat
# 8   data/feffs/Cu1_K_c7_Copper_cif11145\feff0009.dat
# 9   data/feffs/Cu1_K_c7_Copper_cif11145\feff0010.dat
# 10  data/feffs/Cu1_K_c7_Copper_cif11145\feff0011.dat
# 11  data/feffs/Cu1_K_c7_Copper_cif11145\feff0012.dat
# 12  data/feffs/Cu1_K_c7_Copper_cif11145\feff0014.dat
# 13  data/feffs/Cu1_K_c7_Copper_cif11145\feff0015.dat
# 14  data/feffs/Cu1_K_c7_Copper_cif11145\feff0016.dat
# 15  data/feffs/Cu1_K_c7_Copper_cif11145\feff0017.dat
# 16  data/feffs/Cu1_K_c7_Copper_cif11145\feff0018.dat
# 17  data/feffs/Cu1_K_c7_Copper_cif11145\feff0019.dat
# 18  data/feffs/Cu1_K_c7_Copper_cif11145\feff0020.dat
# 19  data/feffs/Cu1_K_c7_Copper_cif11145\feff0021.dat
# 20  data/feffs/Cu1_K_c7_Copper_cif11145\feff0022.dat
# 21  data/feffs/Cu1_K_c7_Copper_cif11145\feff0023.dat
# 22  data/feffs/Cu1_K_c7_Copper_cif11145\feff0024.dat
# 23  data/feffs/Cu1_K_c7_Copper_cif11145\feff0027.dat
# 24  data/feffs/Cu1_K_c7_Copper_cif11145\feff0028.dat

# %%
feffit_paths
# Out:
# {'Cu_2.5562_0': <FeffPath Group label=Cu_2.5562_0, filename=data/feffs/Cu1_K_c7_Copper_cif11145\feff0001.dat>,
#  'Cu_3.615_1': <FeffPath Group label=Cu_3.615_1, filename=data/feffs/Cu1_K_c7_Copper_cif11145\feff0002.dat>,
#  'Cu_3.8342_2': <FeffPath Group label=Cu_3.8342_2, filename=data/feffs/Cu1_K_c7_Copper_cif11145\feff0003.dat>,
#  'Cu_4.3636_3': <FeffPath Group label=Cu_4.3636_3, filename=data/feffs/Cu1_K_c7_Copper_cif11145\feff0004.dat>,
#  'Cu_4.4274_4': <FeffPath Group label=Cu_4.4274_4, filename=data/feffs/Cu1_K_c7_Copper_cif11145\feff0005.dat>,
#  'Cu_4.7699_5': <FeffPath Group label=Cu_4.7699_5, filename=data/feffs/Cu1_K_c7_Copper_cif11145\feff0006.dat>,
#  'Cu_4.7699_6': <FeffPath Group label=Cu_4.7699_6, filename=data/feffs/Cu1_K_c7_Copper_cif11145\feff0007.dat>,
#  'Cu_5.1123_7': <FeffPath Group label=Cu_5.1123_7, filename=data/feffs/Cu1_K_c7_Copper_cif11145\feff0008.dat>,
#  'Cu_5.1123_8': <FeffPath Group label=Cu_5.1123_8, filename=data/feffs/Cu1_K_c7_Copper_cif11145\feff0009.dat>,
#  'Cu_5.1123_9': <FeffPath Group label=Cu_5.1123_9, filename=data/feffs/Cu1_K_c7_Copper_cif11145\feff0010.dat>,
#  'Cu_5.1123_10': <FeffPath Group label=Cu_5.1123_10, filename=data/feffs/Cu1_K_c7_Copper_cif11145\feff0011.dat>,
#  'Cu_5.1123_11': <FeffPath Group label=Cu_5.1123_11, filename=data/feffs/Cu1_K_c7_Copper_cif11145\feff0012.dat>,
#  'Cu_5.1123_12': <FeffPath Group label=Cu_5.1123_12, filename=data/feffs/Cu1_K_c7_Copper_cif11145\feff0014.dat>,
#  'Cu_5.1123_13': <FeffPath Group label=Cu_5.1123_13, filename=data/feffs/Cu1_K_c7_Copper_cif11145\feff0015.dat>,
#  'Cu_5.2993_14': <FeffPath Group label=Cu_5.2993_14, filename=data/feffs/Cu1_K_c7_Copper_cif11145\feff0016.dat>,
#  'Cu_5.7158_15': <FeffPath Group label=Cu_5.7158_15, filename=data/feffs/Cu1_K_c7_Copper_cif11145\feff0017.dat>,
#  'Cu_5.9434_16': <FeffPath Group label=Cu_5.9434_16, filename=data/feffs/Cu1_K_c7_Copper_cif11145\feff0018.dat>,
#  'Cu_5.9434_17': <FeffPath Group label=Cu_5.9434_17, filename=data/feffs/Cu1_K_c7_Copper_cif11145\feff0019.dat>,
#  'Cu_5.9434_18': <FeffPath Group label=Cu_5.9434_18, filename=data/feffs/Cu1_K_c7_Copper_cif11145\feff0020.dat>,
#  'Cu_6.0479_19': <FeffPath Group label=Cu_6.0479_19, filename=data/feffs/Cu1_K_c7_Copper_cif11145\feff0021.dat>,
#  'Cu_6.0479_20': <FeffPath Group label=Cu_6.0479_20, filename=data/feffs/Cu1_K_c7_Copper_cif11145\feff0022.dat>,
#  'Cu_6.0479_21': <FeffPath Group label=Cu_6.0479_21, filename=data/feffs/Cu1_K_c7_Copper_cif11145\feff0023.dat>,
#  'Cu_6.0479_22': <FeffPath Group label=Cu_6.0479_22, filename=data/feffs/Cu1_K_c7_Copper_cif11145\feff0024.dat>,
#  'Cu_6.2613_23': <FeffPath Group label=Cu_6.2613_23, filename=data/feffs/Cu1_K_c7_Copper_cif11145\feff0027.dat>,
#  'Cu_6.3497_24': <FeffPath Group label=Cu_6.3497_24, filename=data/feffs/Cu1_K_c7_Copper_cif11145\feff0028.dat>}
