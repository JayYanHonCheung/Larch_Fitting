# %%
from larch.xafs import feffit, feffit_dataset, feffit_transform, feffit_report
from larch.xafs import pre_edge, autobk, xftf, xftr, ff2chi, feffpath
from larch.fitting import  param_group, param
from larch.io import h5group, read_ascii, read_athena, read_xdi, read_specfile, extract_athenagroup

import os
import copy
import h5py
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# [root] WARNING : Larchs apps and shell are not supported due to missing dependencies: cannot import name 'LarchWxApp' from 'larch.wxlib' (D:\Python\Anaconda3\envs\xraylarch\lib\site-packages\larch\wxlib\__init__.py)

# %%
"""
Plan

1. Organise Cu Standard scripts. (Done)
2. Larch fit data_1 of 9. (Done)
3. Organise script for data_1. (Done)
4. Simultaneous fit of data 2 - 9 w/ script. (Done)
5. Compare results with Artemis and Larch (if sigma2 optimised as constrain.) (Not important)
6. Improve fitting by rebinning either in time-axis or EXAFS region. (Didn't work so well.)
7. Improve fitting by cropping and recalibrating all 9000 spectra in DAWN (in LARCH in the future).
8. Fit all 9000 spectra.
9. Improvise, Adapt, Overcome.

"""

# %%
""" 0. Preparing Data. """

data_dir = r"..\Data\Larch_Fitting\time_series_2"
fnames = [fname for fname in os.listdir(data_dir)]
path_list = [os.path.join(data_dir, fname) for fname in fnames]

# %%
""" 1. Batch Reading Data """

# Initialisation
data_list = [read_ascii(fpath, labels="null energy mu") for fpath in path_list]
for data, fname in zip(data_list, fnames):
    data.groupname = fname

# Pre-processing - EXAFS fittings only need a valid k space
    autobk(data, rbkg=1.00) # Need to have option to suppress normalisation in case loaded spectra is already normed
#     xftf(data, kmin=3.0, kmax=10, dk=1.0, window="hanning", kweight=2.00)
#     xftr(data, rmin=1.0, rmax=4.0, dr=1.0, window="hanning")

# %%
len(data_list)
# Out:
# 10

# %%
""" Misc: Plotting """
def plot(data_list, index):
    energy = data_list[index].energy
    mu = data_list[index].mu
    norm = data_list[index].norm
    chi = data_list[index].chi
    k = data_list[index].k
    chir_mag = data_list[index].chir_mag
    r = data_list[index].r

    fig, ax = plt.subplots(1, 3, figsize=(15, 5))

    ax[0].plot(energy, norm)
    ax[1].plot(k, chi)
    ax[2].plot(r, chir_mag)
    
plot(data_list, 0)

# %%
""" 2.1 Setup feffit - feffit parameters + FT and fitting space """

# Create feffit Parameter Group to hold fit parameters (Core parameters)
_feffit_params = param_group(s02=param(0.87348, min=0, vary=False),
                             e0=param(0.1, min=-10, max=10, vary=True),
                             sigma2_cu=param(0.008, min=0.001, max=0.009, vary=True),
                             sigma2_o=param(0.008, min=0.001, max=0.009, vary=True))

# Create feffit Parameter Group to hold fit parameters (Repeating parameters)
data_num = len(data_list)

fit_params = ["n_cucu_", "n_cuo_", "delr_cu_", "delr_o_"]
fit_values = [param(1.0, vary=True),
              param(1.0, vary=True),
              param(0.001, min=-0.5, max=0.5, vary=True),
              param(0.001, min=-0.5, max=0.5, vary=True)]

all_fit_params = [param + str(i) for i in range(data_num) for param in fit_params]
all_fit_values = fit_values * data_num

for key, value in zip(all_fit_params, all_fit_values):
    setattr(_feffit_params, key, value)

# Define Fourier transform and fitting space
# Actual FT parameters for EXAFS fitting
_feffit_trans = feffit_transform(kmin=3.000, kmax=10.000, dk=3.0000, kw=2,
                                 window="hanning", fitspace='r', rmin=1.000, rmax=4.000)

# %%
""" 2.2 Setup up paths for all datasets. """

# Create list of base paths
_paths = []

_paths_names = ["Cu256_", "O195_"]
_all_paths_names = [pname + str(i) for i in range(data_num) for pname in _paths_names]

_path_cu = feffpath(r"data/feffs/Cu1_K_c7_Copper_cif11145/feff0001.dat",
                degen=1, e0='e0', sigma2='sigma2_cu')
_path_o = feffpath(r"data/feffs/Cu1_K_c7_Tenorite_cif11639/feff0001.dat",
               degen=1, e0='e0', sigma2='sigma2_o')

_path_keys = ["label", "s02", "deltar"]
_path_values_cu = ["Cu256_", "s02 * n_cucu_", "delr_cu_"]
_path_values_o = ["O195_", "s02 * n_cuo_", "delr_o_"]

for i in range(data_num):
    
    # Setup for Cu-Cu paths
    _path_cu_temp = copy.deepcopy(_path_cu)
    for key, value in zip(_path_keys, _path_values_cu):
        setattr(_path_cu_temp, key, value + str(i))

    # Setup for Cu-O paths    
    _path_o_temp = copy.deepcopy(_path_o)
    for key, value in zip(_path_keys, _path_values_o):
        setattr(_path_o_temp, key, value + str(i))
        
    _paths_dict = {_paths_names[0] + str(i): _path_cu_temp,
                   _paths_names[1] + str(i): _path_o_temp}
    
    _paths.append(_paths_dict)

# %%
_feffit_params
# Out:
# <Param Group 0x22122136d30>

# %%
_pathsum = ff2chi(_paths[0], paramgroup=_feffit_params)

# %%
""" 2.3 Make dict of paths, sum them using a group of parameters. """
_ff2chi_paths_list = copy.deepcopy(_paths)

for _ff2chi_paths in _ff2chi_paths_list:
    if len(_ff2chi_paths) > 0:
        _pathsum = ff2chi(_ff2chi_paths, paramgroup=_feffit_params)

# %%
""" 2.4 Build and Run feffit dataset"""
_feffit_dataset_list = [feffit_dataset(data=data, paths=path, transform=_feffit_trans) for data, path in zip(data_list, _paths)]
_feffit_result = feffit(_feffit_params, _feffit_dataset_list)

# _feffit_dataset = feffit_dataset(data=data, transform=_feffit_trans, paths=_ff2chi_paths)
# _feffit_result = feffit(_feffit_params, _feffit_dataset) # _feffit_dataset can be a list***

# Insert _feffit_result into self.feffit_history
# if not hasattr(data, 'feffit_history'): 
#     data.feffit_history = []    
# _feffit_result.label = 'Fit %i' % (1+len(data.feffit_history))
# data.feffit_history.insert(0, _feffit_result)

# %%
""" Misc: Plotting fitted results"""
for i, result in enumerate(_feffit_result.datasets):

    data_r = result.data.r
    data_chir_mag = result.data.chir_mag

    fit_r = result.model.r
    fit_chir_mag = result.model.chir_mag

    a = result.paths["Cu256_" + str(i)].r
    b = result.paths["Cu256_" + str(i)].chir_mag

    c = result.paths["O195_" + str(i)].r
    d = result.paths["O195_" + str(i)].chir_mag

    fig = plt.figure(figsize=(12, 6))
    plt.plot(fit_r, fit_chir_mag, color="r", label="fit")
    plt.plot(data_r, data_chir_mag, lw=0, marker='o', markersize=3, fillstyle='none', color="k", label="Raw Data")
    plt.plot(a, b, label="Cu-Cu")
    plt.plot(c, d, label="Cu-O")
    plt.axhline(0, color="k", linestyle=":")
    plt.legend()

# %%
""" Misc: Print fitted results. """
print(feffit_report(_feffit_result))
# Out:
# =================== FEFFIT RESULTS ====================
# [[Statistics]]
#    nvarys, npts       =  43, 1960
#    n_independent      =  143.690
#    chi_square         =  477.565600
#    reduced chi_square =  4.74292262
#    r-factor           =  0.04069866
#    Akaike info crit   =  258.577947
#    Bayesian info crit =  386.187295
#
# [[Datasets (10)]]
#  dataset 1:
#    fit space          = 'r'
#    r-range            = 1.000, 4.000
#    k-range            = 3.000, 10.000
#    k window, dk       = 'hanning', 3.000
#    paths used in fit  = ['C:/Users/user/larch/feff/Cu1_K_Copper_cif11145/feff0001.dat', 'C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat']
#    k-weight           = 2
#    epsilon_k          = Array(mean=0.00405697, std=0.00559839)
#    epsilon_r          = 0.03614665
#    n_independent      = 14.369
#  dataset 2:
#    fit space          = 'r'
#    r-range            = 1.000, 4.000
#    k-range            = 3.000, 10.000
#    k window, dk       = 'hanning', 3.000
#    paths used in fit  = ['C:/Users/user/larch/feff/Cu1_K_Copper_cif11145/feff0001.dat', 'C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat']
#    k-weight           = 2
#    epsilon_k          = Array(mean=0.00431964, std=0.00615823)
#    epsilon_r          = 0.03848700
#    n_independent      = 14.369
#  dataset 3:
#    fit space          = 'r'
#    r-range            = 1.000, 4.000
#    k-range            = 3.000, 10.000
#    k window, dk       = 'hanning', 3.000
#    paths used in fit  = ['C:/Users/user/larch/feff/Cu1_K_Copper_cif11145/feff0001.dat', 'C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat']
#    k-weight           = 2
#    epsilon_k          = Array(mean=0.00426331, std=0.00619331)
#    epsilon_r          = 0.03798511
#    n_independent      = 14.369
#  dataset 4:
#    fit space          = 'r'
#    r-range            = 1.000, 4.000
#    k-range            = 3.000, 10.000
#    k window, dk       = 'hanning', 3.000
#    paths used in fit  = ['C:/Users/user/larch/feff/Cu1_K_Copper_cif11145/feff0001.dat', 'C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat']
#    k-weight           = 2
#    epsilon_k          = Array(mean=0.00404869, std=0.00563965)
#    epsilon_r          = 0.03607293
#    n_independent      = 14.369
#  dataset 5:
#    fit space          = 'r'
#    r-range            = 1.000, 4.000
#    k-range            = 3.000, 10.000
#    k window, dk       = 'hanning', 3.000
#    paths used in fit  = ['C:/Users/user/larch/feff/Cu1_K_Copper_cif11145/feff0001.dat', 'C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat']
#    k-weight           = 2
#    epsilon_k          = Array(mean=0.00401111, std=0.00560743)
#    epsilon_r          = 0.03573810
#    n_independent      = 14.369
#  dataset 6:
#    fit space          = 'r'
#    r-range            = 1.000, 4.000
#    k-range            = 3.000, 10.000
#    k window, dk       = 'hanning', 3.000
#    paths used in fit  = ['C:/Users/user/larch/feff/Cu1_K_Copper_cif11145/feff0001.dat', 'C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat']
#    k-weight           = 2
#    epsilon_k          = Array(mean=0.00431931, std=0.00616508)
#    epsilon_r          = 0.03848406
#    n_independent      = 14.369
#  dataset 7:
#    fit space          = 'r'
#    r-range            = 1.000, 4.000
#    k-range            = 3.000, 10.000
#    k window, dk       = 'hanning', 3.000
#    paths used in fit  = ['C:/Users/user/larch/feff/Cu1_K_Copper_cif11145/feff0001.dat', 'C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat']
#    k-weight           = 2
#    epsilon_k          = Array(mean=0.00366316, std=0.00510790)
#    epsilon_r          = 0.03263793
#    n_independent      = 14.369
#  dataset 8:
#    fit space          = 'r'
#    r-range            = 1.000, 4.000
#    k-range            = 3.000, 10.000
#    k window, dk       = 'hanning', 3.000
#    paths used in fit  = ['C:/Users/user/larch/feff/Cu1_K_Copper_cif11145/feff0001.dat', 'C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat']
#    k-weight           = 2
#    epsilon_k          = Array(mean=0.00393341, std=0.00564353)
#    epsilon_r          = 0.03504579
#    n_independent      = 14.369
#  dataset 9:
#    fit space          = 'r'
#    r-range            = 1.000, 4.000
#    k-range            = 3.000, 10.000
#    k window, dk       = 'hanning', 3.000
#    paths used in fit  = ['C:/Users/user/larch/feff/Cu1_K_Copper_cif11145/feff0001.dat', 'C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat']
#    k-weight           = 2
#    epsilon_k          = Array(mean=0.00367142, std=0.00506040)
#    epsilon_r          = 0.03271153
#    n_independent      = 14.369
#  dataset 10:
#    fit space          = 'r'
#    r-range            = 1.000, 4.000
#    k-range            = 3.000, 10.000
#    k window, dk       = 'hanning', 3.000
#    paths used in fit  = ['C:/Users/user/larch/feff/Cu1_K_Copper_cif11145/feff0001.dat', 'C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat']
#    k-weight           = 2
#    epsilon_k          = Array(mean=0.00422588, std=0.00618076)
#    epsilon_r          = 0.03765163
#    n_independent      = 14.369
#
# [[Variables]]
#    delr_cu_0      = -0.07019893 +/- 0.26477858   (init=  1.0000e-03)
#    delr_cu_1      =  0.01918897 +/- 0.10413402   (init=  1.0000e-03)
#    delr_cu_2      =  0.36067869 +/- 0.16850605   (init=  1.0000e-03)
#    delr_cu_3      = -0.08943674 +/- 0.13312618   (init=  1.0000e-03)
#    delr_cu_4      = -0.11959532 +/- 0.11639112   (init=  1.0000e-03)
#    delr_cu_5      = -0.28160706 +/- 0.13708910   (init=  1.0000e-03)
#    delr_cu_6      = -0.03770537 +/- 0.06932192   (init=  1.0000e-03)
#    delr_cu_7      = -0.10866065 +/- 0.11081782   (init=  1.0000e-03)
#    delr_cu_8      = -0.00356745 +/- 0.08818889   (init=  1.0000e-03)
#    delr_cu_9      = -0.11110534 +/- 0.16671100   (init=  1.0000e-03)
#    delr_o_0       =  0.00276660 +/- 0.00716637   (init=  1.0000e-03)
#    delr_o_1       =  0.00127246 +/- 0.00735069   (init=  1.0000e-03)
#    delr_o_2       =  1.0896e-04 +/- 0.00721987   (init=  1.0000e-03)
#    delr_o_3       =  0.00284808 +/- 0.00716262   (init=  1.0000e-03)
#    delr_o_4       =  0.00142760 +/- 0.00721640   (init=  1.0000e-03)
#    delr_o_5       =  8.8161e-04 +/- 0.00756216   (init=  1.0000e-03)
#    delr_o_6       =  0.00968185 +/- 0.00682387   (init=  1.0000e-03)
#    delr_o_7       =  0.00383258 +/- 0.00714962   (init=  1.0000e-03)
#    delr_o_8       =  0.00949297 +/- 0.00679985   (init=  1.0000e-03)
#    delr_o_9       =  0.00219457 +/- 0.00725229   (init=  1.0000e-03)
#    e0             = -0.49309572 +/- 0.64278925   (init=  0.10000000)
#    n_cucu_0       = -0.02727319 +/- 0.12538373   (init=  1.00000000)
#    n_cucu_1       =  0.08118745 +/- 0.21315979   (init=  1.00000000)
#    n_cucu_2       =  0.06657987 +/- 0.22381504   (init=  1.00000000)
#    n_cucu_3       = -0.05336785 +/- 0.15405123   (init=  1.00000000)
#    n_cucu_4       = -0.05920221 +/- 0.16149990   (init=  1.00000000)
#    n_cucu_5       =  0.04717848 +/- 0.13889425   (init=  1.00000000)
#    n_cucu_6       = -0.09919540 +/- 0.22383934   (init=  1.00000000)
#    n_cucu_7       = -0.06150466 +/- 0.16368097   (init=  1.00000000)
#    n_cucu_8       = -0.08040762 +/- 0.19348035   (init=  1.00000000)
#    n_cucu_9       = -0.04371039 +/- 0.14441311   (init=  1.00000000)
#    n_cuo_0        =  3.65580942 +/- 0.30370813   (init=  1.00000000)
#    n_cuo_1        =  3.74889612 +/- 0.32411803   (init=  1.00000000)
#    n_cuo_2        =  3.77189457 +/- 0.31699951   (init=  1.00000000)
#    n_cuo_3        =  3.69235851 +/- 0.30485040   (init=  1.00000000)
#    n_cuo_4        =  3.67012847 +/- 0.30484461   (init=  1.00000000)
#    n_cuo_5        =  3.83708482 +/- 0.32107892   (init=  1.00000000)
#    n_cuo_6        =  3.61914465 +/- 0.28220658   (init=  1.00000000)
#    n_cuo_7        =  3.65298306 +/- 0.30028720   (init=  1.00000000)
#    n_cuo_8        =  3.60474130 +/- 0.28224586   (init=  1.00000000)
#    n_cuo_9        =  3.79110087 +/- 0.31754963   (init=  1.00000000)
#    s02            =  0.87348000 (fixed)
#    sigma2_cu      =  0.00100000 +/- 0.01620633   (init=  0.00800000)
#    sigma2_o       =  0.00540494 +/- 7.5363e-04   (init=  0.00800000)
#
# [[Correlations]]    (unreported correlations are <  0.100)
#    n_cucu_6, sigma2_cu  = -0.881
#    n_cucu_8, sigma2_cu  = -0.824
#    n_cucu_1, sigma2_cu  =  0.785
#    n_cucu_7, sigma2_cu  = -0.761
#    n_cucu_4, sigma2_cu  = -0.748
#    n_cucu_6, n_cucu_8   =  0.727
#    n_cucu_1, n_cucu_6   = -0.691
#    n_cucu_3, sigma2_cu  = -0.690
#    n_cucu_6, n_cucu_7   =  0.670
#    n_cucu_5, sigma2_cu  =  0.670
#    n_cucu_4, n_cucu_6   =  0.659
#    n_cucu_1, n_cucu_8   = -0.646
#    n_cucu_7, n_cucu_8   =  0.626
#    n_cucu_9, sigma2_cu  = -0.615
#    n_cucu_4, n_cucu_8   =  0.615
#    n_cuo_7, sigma2_o    =  0.613
#    n_cuo_4, sigma2_o    =  0.612
#    n_cuo_6, sigma2_o    =  0.611
#    n_cuo_8, sigma2_o    =  0.609
#    n_cucu_3, n_cucu_6   =  0.609
#    n_cucu_2, sigma2_cu  =  0.609
#    n_cuo_3, sigma2_o    =  0.600
#    n_cuo_9, sigma2_o    =  0.600
#    n_cuo_1, sigma2_o    =  0.599
#    n_cucu_1, n_cucu_7   = -0.598
#    n_cuo_0, sigma2_o    =  0.595
#    n_cucu_5, n_cucu_6   = -0.593
#    n_cuo_2, sigma2_o    =  0.591
#    n_cucu_1, n_cucu_4   = -0.589
#    delr_o_6, e0         =  0.589
#    delr_o_8, e0         =  0.587
#    n_cucu_4, n_cucu_7   =  0.571
#    n_cucu_3, n_cucu_8   =  0.569
#    delr_o_7, e0         =  0.564
#    delr_o_3, e0         =  0.560
#    delr_o_4, e0         =  0.559
#    delr_o_0, e0         =  0.558
#    delr_o_9, e0         =  0.554
#    n_cucu_5, n_cucu_8   = -0.554
#    delr_o_2, e0         =  0.550
#    delr_o_5, e0         =  0.549
#    delr_o_1, e0         =  0.544
#    n_cucu_6, n_cucu_9   =  0.542
#    n_cucu_1, n_cucu_3   = -0.542
#    n_cuo_5, sigma2_o    =  0.538
#    n_cucu_2, n_cucu_6   = -0.536
#    n_cucu_3, n_cucu_7   =  0.527
#    n_cucu_1, n_cucu_5   =  0.526
#    n_cucu_3, n_cucu_4   =  0.518
#    n_cucu_5, n_cucu_7   = -0.514
#    n_cucu_8, n_cucu_9   =  0.506
#    n_cucu_4, n_cucu_5   = -0.505
#    n_cucu_2, n_cucu_8   = -0.501
#    n_cucu_1, n_cucu_9   = -0.484
#    n_cucu_1, n_cucu_2   =  0.478
#    n_cucu_7, n_cucu_9   =  0.471
#    n_cucu_3, n_cucu_5   = -0.467
#    n_cucu_2, n_cucu_7   = -0.464
#    n_cucu_4, n_cucu_9   =  0.463
#    n_cucu_2, n_cucu_4   = -0.457
#    n_cucu_3, n_cucu_9   =  0.427
#    n_cucu_2, n_cucu_3   = -0.421
#    n_cucu_0, sigma2_cu  = -0.419
#    n_cucu_5, n_cucu_9   = -0.417
#    n_cucu_2, n_cucu_5   =  0.410
#    sigma2_cu, sigma2_o  = -0.404
#    n_cuo_6, n_cuo_8     =  0.386
#    n_cuo_4, n_cuo_7     =  0.383
#    n_cuo_6, n_cuo_7     =  0.381
#    n_cuo_7, n_cuo_8     =  0.381
#    n_cuo_4, n_cuo_6     =  0.380
#    n_cuo_4, n_cuo_8     =  0.379
#    n_cucu_2, n_cucu_9   = -0.376
#    n_cuo_3, n_cuo_7     =  0.375
#    n_cuo_3, n_cuo_6     =  0.375
#    n_cuo_7, n_cuo_9     =  0.375
#    n_cuo_1, n_cuo_7     =  0.375
#    n_cuo_3, n_cuo_8     =  0.374
#    n_cuo_3, n_cuo_4     =  0.374
#    n_cuo_1, n_cuo_4     =  0.374
#    n_cuo_4, n_cuo_9     =  0.374
#    n_cuo_6, n_cuo_9     =  0.373
#    n_cuo_8, n_cuo_9     =  0.373
#    n_cuo_0, n_cuo_6     =  0.372
#    n_cuo_0, n_cuo_7     =  0.372
#    n_cuo_0, n_cuo_8     =  0.371
#    n_cucu_0, n_cucu_6   =  0.371
#    n_cuo_0, n_cuo_4     =  0.370
#    n_cuo_1, n_cuo_6     =  0.370
#    n_cuo_2, n_cuo_7     =  0.369
#    n_cuo_2, n_cuo_6     =  0.369
#    n_cuo_1, n_cuo_8     =  0.369
#    n_cuo_2, n_cuo_8     =  0.369
#    n_cuo_2, n_cuo_4     =  0.368
#    delr_o_6, delr_o_7   =  0.368
#    n_cuo_3, n_cuo_9     =  0.367
#    delr_o_6, delr_o_8   =  0.367
#    n_cuo_1, n_cuo_9     =  0.366
#    n_cuo_1, n_cuo_3     =  0.366
#    delr_o_4, delr_o_6   =  0.365
#    n_cuo_0, n_cuo_3     =  0.364
#    n_cuo_0, n_cuo_9     =  0.363
#    n_cuo_0, n_cuo_1     =  0.362
#    n_cuo_2, n_cuo_3     =  0.362
#    delr_o_4, delr_o_7   =  0.362
#    n_cuo_2, n_cuo_9     =  0.361
#    delr_o_3, delr_o_6   =  0.360
#    n_cuo_1, n_cuo_2     =  0.360
#    n_cuo_0, n_cuo_2     =  0.359
#    delr_o_5, delr_o_6   =  0.358
#    delr_o_6, delr_o_9   =  0.357
#    delr_o_7, delr_o_8   =  0.355
#    delr_o_3, delr_o_7   =  0.355
#    delr_o_5, delr_o_7   =  0.353
#    delr_o_0, delr_o_6   =  0.353
#    delr_o_4, delr_o_8   =  0.352
#    delr_o_3, delr_o_4   =  0.352
#    delr_o_7, delr_o_9   =  0.351
#    delr_o_4, delr_o_5   =  0.351
#    delr_o_3, delr_o_8   =  0.350
#    delr_o_4, delr_o_9   =  0.349
#    delr_o_8, delr_o_9   =  0.347
#    n_cucu_0, n_cucu_8   =  0.347
#    delr_o_5, delr_o_8   =  0.347
#    delr_o_2, delr_o_6   =  0.347
#    delr_o_0, delr_o_8   =  0.346
#    n_cucu_1, sigma2_o   = -0.345
#    delr_o_3, delr_o_5   =  0.345
#    delr_o_1, delr_o_6   =  0.344
#    delr_o_0, delr_o_7   =  0.344
#    delr_o_3, delr_o_9   =  0.344
#    delr_o_5, delr_o_9   =  0.341
#    delr_o_0, delr_o_4   =  0.341
#    delr_o_2, delr_o_8   =  0.341
#    n_cuo_5, n_cuo_6     =  0.341
#    n_cuo_5, n_cuo_8     =  0.340
#    delr_o_0, delr_o_3   =  0.338
#    delr_o_1, delr_o_8   =  0.338
#    delr_o_2, delr_o_7   =  0.337
#    delr_o_1, delr_o_7   =  0.336
#    delr_o_0, delr_o_5   =  0.335
#    delr_o_2, delr_o_4   =  0.335
#    delr_o_0, delr_o_9   =  0.335
#    n_cuo_5, n_cuo_7     =  0.334
#    delr_o_1, delr_o_4   =  0.334
#    n_cucu_4, sigma2_o   =  0.333
#    n_cuo_4, n_cuo_5     =  0.333
#    delr_o_2, delr_o_3   =  0.332
#    delr_o_1, delr_o_3   =  0.330
#    n_cuo_3, n_cuo_5     =  0.329
#    delr_o_2, delr_o_5   =  0.329
#    delr_o_2, delr_o_9   =  0.329
#    n_cucu_6, sigma2_o   =  0.328
#    n_cucu_7, sigma2_o   =  0.328
#    n_cucu_0, n_cucu_1   = -0.328
#    delr_o_1, delr_o_5   =  0.327
#    n_cuo_5, n_cuo_9     =  0.327
#    delr_o_1, delr_o_9   =  0.327
#    n_cuo_0, n_cuo_5     =  0.327
#    delr_o_0, delr_o_2   =  0.327
#    n_cuo_2, n_cuo_5     =  0.324
#    delr_o_0, delr_o_1   =  0.324
#    n_cuo_1, n_cuo_5     =  0.324
#    n_cucu_0, n_cucu_7   =  0.320
#    delr_o_1, delr_o_2   =  0.319
#    n_cucu_0, n_cucu_4   =  0.314
#    n_cucu_8, sigma2_o   =  0.295
#    n_cucu_0, n_cucu_3   =  0.292
#    n_cucu_0, n_cucu_5   = -0.286
#    n_cuo_1, sigma2_cu   = -0.280
#    n_cucu_3, sigma2_o   =  0.277
#    n_cucu_9, sigma2_o   =  0.274
#    n_cuo_4, sigma2_cu   = -0.266
#    n_cucu_5, sigma2_o   = -0.266
#    n_cucu_0, n_cucu_9   =  0.259
#    n_cuo_7, sigma2_cu   = -0.258
#    n_cucu_0, n_cucu_2   = -0.256
#    n_cucu_2, sigma2_o   = -0.254
#    n_cuo_9, sigma2_cu   = -0.247
#    n_cucu_1, n_cuo_1    = -0.242
#    n_cucu_6, n_cuo_1    =  0.233
#    n_cuo_3, sigma2_cu   = -0.232
#    n_cucu_4, n_cuo_1    =  0.230
#    n_cucu_7, n_cuo_1    =  0.228
#    n_cuo_2, sigma2_cu   = -0.226
#    n_cucu_1, n_cuo_4    = -0.226
#    n_cuo_0, sigma2_cu   = -0.223
#    n_cucu_6, n_cuo_4    =  0.220
#    n_cucu_1, n_cuo_7    = -0.220
#    n_cucu_7, n_cuo_4    =  0.219
#    n_cucu_4, n_cuo_7    =  0.215
#    n_cucu_6, n_cuo_7    =  0.213
#    delr_cu_6, n_cucu_6  = -0.212
#    n_cucu_1, n_cuo_9    = -0.211
#    n_cucu_8, n_cuo_1    =  0.210
#    delr_cu_6, sigma2_cu =  0.208
#    n_cucu_4, n_cuo_9    =  0.207
#    n_cucu_7, n_cuo_9    =  0.204
#    n_cucu_6, n_cuo_9    =  0.204
#    delr_o_4, sigma2_cu  = -0.201
#    delr_o_7, sigma2_cu  = -0.201
#    n_cucu_1, n_cuo_3    = -0.199
#    n_cucu_8, n_cuo_4    =  0.198
#    n_cucu_4, n_cuo_4    =  0.197
#    n_cucu_3, n_cuo_1    =  0.196
#    n_cucu_4, n_cuo_3    =  0.195
#    n_cucu_1, n_cuo_2    = -0.194
#    n_cucu_5, n_cuo_1    = -0.193
#    n_cucu_7, n_cuo_3    =  0.192
#    n_cucu_1, n_cuo_0    = -0.192
#    n_cucu_8, n_cuo_7    =  0.191
#    n_cucu_4, n_cuo_2    =  0.191
#    n_cucu_9, n_cuo_1    =  0.191
#    n_cucu_7, n_cuo_7    =  0.190
#    n_cucu_6, n_cuo_3    =  0.190
#    n_cucu_4, n_cuo_0    =  0.189
#    n_cucu_7, n_cuo_2    =  0.188
#    n_cucu_3, n_cuo_4    =  0.187
#    n_cucu_7, n_cuo_0    =  0.186
#    n_cucu_6, n_cuo_2    =  0.185
#    delr_cu_8, n_cucu_8  = -0.185
#    n_cucu_5, n_cuo_4    = -0.184
#    delr_cu_8, sigma2_cu =  0.183
#    n_cucu_9, n_cuo_4    =  0.183
#    n_cucu_8, n_cuo_9    =  0.183
#    n_cucu_6, n_cuo_0    =  0.182
#    n_cucu_3, n_cuo_7    =  0.181
#    delr_o_5, sigma2_cu  = -0.179
#    n_cuo_8, sigma2_cu   = -0.179
#    n_cucu_5, n_cuo_7    = -0.179
#    n_cucu_9, n_cuo_7    =  0.178
#    n_cuo_6, sigma2_cu   = -0.178
#    delr_cu_5, sigma2_o  =  0.178
#    n_cucu_2, n_cuo_1    = -0.176
#    n_cucu_3, n_cuo_9    =  0.174
#    delr_cu_6, n_cucu_8  = -0.173
#    e0, n_cuo_6          = -0.173
#    e0, n_cuo_8          = -0.173
#    n_cucu_5, n_cuo_9    = -0.171
#    n_cucu_8, n_cuo_3    =  0.170
#    n_cucu_2, n_cuo_4    = -0.168
#    n_cucu_8, n_cuo_2    =  0.165
#    delr_o_3, sigma2_cu  = -0.164
#    n_cucu_2, n_cuo_7    = -0.163
#    n_cucu_8, n_cuo_0    =  0.163
#    n_cucu_9, n_cuo_3    =  0.162
#    delr_cu_6, n_cucu_1  =  0.162
#    delr_o_9, sigma2_cu  = -0.162
#    delr_o_4, n_cucu_6   =  0.162
#    delr_o_7, n_cucu_6   =  0.161
#    n_cucu_5, n_cuo_3    = -0.161
#    delr_cu_8, n_cucu_6  = -0.161
#    delr_o_4, n_cucu_1   = -0.160
#    e0, n_cuo_3          = -0.159
#    n_cucu_3, n_cuo_2    =  0.159
#    delr_o_7, n_cucu_1   = -0.159
#    e0, n_cuo_7          = -0.159
#    n_cucu_9, n_cuo_2    =  0.158
#    n_cucu_1, n_cuo_8    = -0.158
#    e0, n_cuo_0          = -0.158
#    n_cucu_1, n_cuo_6    = -0.158
#    delr_cu_6, n_cucu_7  = -0.157
#    n_cucu_3, n_cuo_0    =  0.157
#    n_cucu_4, n_cuo_8    =  0.157
#    n_cucu_5, n_cuo_2    = -0.157
#    e0, n_cuo_2          = -0.157
#    n_cucu_9, n_cuo_0    =  0.157
#    e0, n_cuo_4          = -0.157
#    n_cucu_2, n_cuo_9    = -0.157
#    n_cucu_4, n_cuo_6    =  0.157
#    e0, n_cuo_9          = -0.156
#    delr_o_4, n_cucu_8   =  0.156
#    n_cucu_5, n_cuo_0    = -0.155
#    delr_o_7, n_cucu_8   =  0.155
#    delr_cu_6, n_cucu_4  = -0.154
#    n_cucu_7, n_cuo_8    =  0.153
#    n_cucu_7, n_cuo_6    =  0.152
#    e0, n_cuo_1          = -0.150
#    delr_cu_5, delr_o_5  =  0.148
#    n_cucu_2, n_cuo_3    = -0.147
#    delr_o_6, sigma2_cu  = -0.145
#    delr_cu_8, n_cucu_1  =  0.144
#    n_cucu_9, n_cuo_9    =  0.144
#    delr_cu_6, n_cucu_3  = -0.144
#    n_cucu_0, sigma2_o   =  0.143
#    delr_o_5, n_cucu_1   = -0.142
#    n_cucu_6, n_cuo_8    =  0.142
#    n_cucu_3, n_cuo_3    =  0.142
#    n_cucu_2, n_cuo_0    = -0.142
#    delr_o_5, n_cucu_6   =  0.142
#    delr_cu_6, n_cucu_5  =  0.140
#    n_cuo_5, sigma2_cu   = -0.139
#    delr_cu_8, n_cucu_7  = -0.139
#    delr_cu_8, n_cucu_4  = -0.137
#    delr_o_5, n_cucu_8   =  0.137
#    n_cucu_6, n_cuo_6    =  0.137
#    e0, n_cuo_5          = -0.135
#    delr_cu_1, n_cucu_1  =  0.134
#    delr_o_4, n_cucu_7   =  0.132
#    delr_o_7, n_cucu_4   =  0.131
#    n_cucu_9, n_cuo_8    =  0.131
#    n_cucu_9, n_cuo_6    =  0.130
#    delr_o_3, n_cucu_1   = -0.130
#    delr_o_9, n_cucu_1   = -0.129
#    delr_o_3, n_cucu_6   =  0.128
#    delr_cu_6, n_cucu_9  = -0.127
#    delr_o_9, n_cucu_6   =  0.127
#    n_cucu_3, n_cuo_8    =  0.127
#    delr_cu_6, n_cucu_2  =  0.126
#    n_cucu_3, n_cuo_6    =  0.126
#    n_cucu_5, n_cuo_8    = -0.126
#    delr_cu_8, n_cucu_3  = -0.126
#    n_cucu_5, n_cuo_6    = -0.125
#    n_cucu_1, n_cuo_5    = -0.125
#    delr_o_3, n_cucu_8   =  0.125
#    n_cucu_4, n_cuo_5    =  0.124
#    n_cucu_8, n_cuo_6    =  0.124
#    e0, sigma2_o         = -0.124
#    delr_o_9, n_cucu_8   =  0.123
#    n_cucu_8, n_cuo_8    =  0.122
#    delr_cu_1, sigma2_cu =  0.122
#    delr_cu_8, n_cucu_5  =  0.121
#    n_cucu_7, n_cuo_5    =  0.120
#    delr_o_5, sigma2_o   =  0.119
#    delr_o_4, n_cucu_4   =  0.118
#    n_cucu_2, n_cuo_2    = -0.118
#    delr_o_5, n_cucu_4   =  0.116
#    delr_o_5, n_cucu_7   =  0.116
#    delr_o_4, sigma2_o   =  0.115
#    n_cucu_2, n_cuo_8    = -0.115
#    delr_o_6, n_cucu_1   = -0.115
#    n_cucu_2, n_cuo_6    = -0.115
#    delr_o_1, sigma2_cu  = -0.113
#    delr_o_7, sigma2_o   =  0.113
#    delr_o_4, n_cucu_2   = -0.113
#    delr_o_7, n_cucu_7   =  0.113
#    delr_o_7, n_cucu_2   = -0.113
#    delr_o_4, n_cucu_3   =  0.113
#    delr_cu_8, n_cucu_9  = -0.112
#    delr_o_7, n_cucu_3   =  0.112
#    delr_cu_8, n_cucu_2  =  0.111
#    delr_o_0, sigma2_cu  = -0.111
#    delr_cu_5, n_cuo_6   =  0.110
#    delr_cu_5, n_cuo_8   =  0.110
#    delr_cu_1, n_cucu_6  = -0.110
#    delr_o_5, n_cuo_5    =  0.110
#    delr_o_6, n_cucu_8   =  0.109
#    n_cucu_6, n_cuo_5    =  0.108
#    delr_cu_4, delr_o_4  =  0.107
#    n_cucu_0, n_cuo_1    =  0.106
#    delr_cu_5, n_cuo_7   =  0.105
#    delr_cu_5, n_cuo_3   =  0.105
#    delr_cu_5, n_cuo_4   =  0.104
#    delr_cu_5, n_cuo_0   =  0.104
#    delr_cu_5, n_cuo_9   =  0.103
#    n_cucu_9, n_cuo_5    =  0.103
#    delr_o_3, n_cucu_4   =  0.103
#    delr_cu_5, n_cuo_2   =  0.103
#    delr_o_3, n_cucu_7   =  0.103
#    delr_cu_1, n_cucu_8  = -0.103
#    delr_o_6, n_cucu_6   =  0.103
#    delr_o_9, n_cucu_4   =  0.102
#    delr_o_9, n_cucu_7   =  0.102
#    delr_cu_5, n_cuo_1   =  0.101
#    n_cucu_0, n_cuo_4    =  0.100
#    delr_o_5, n_cucu_2   = -0.100
#
# [[Paths]]
#  dataset 1:
#  = Path 'Cu256_0' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Copper_cif11145/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#               Cu      -1.8075, -0.0000, -1.8075  1
#      reff   =  2.55620000
#      degen  =  1.00000000
#      n*s02  = -0.02382259 +/- 0.10952018  := 's02 * n_cucu_0'
#      e0     = -0.49309572 +/- 0.64278925  := 'e0'
#      r      =  2.48600107 +/- 0.26477858  := 'reff + delr_cu_0'
#      deltar = -0.07019893 +/- 0.26477858  := 'delr_cu_0'
#      sigma2 =  0.00100000 +/- 0.01620633  := 'sigma2_cu'
#
#  = Path 'O195_0' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#                O      -1.1474,  1.1389, -1.0854  2
#      reff   =  1.94720000
#      degen  =  1.00000000
#      n*s02  =  3.19327641 +/- 0.26528298  := 's02 * n_cuo_0'
#      e0     = -0.49309572 +/- 0.64278925  := 'e0'
#      r      =  1.94996660 +/- 0.00716637  := 'reff + delr_o_0'
#      deltar =  0.00276660 +/- 0.00716637  := 'delr_o_0'
#      sigma2 =  0.00540494 +/- 7.5363e-04  := 'sigma2_o'
#
#  dataset 2:
#  = Path 'Cu256_1' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Copper_cif11145/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#               Cu      -1.8075, -0.0000, -1.8075  1
#      reff   =  2.55620000
#      degen  =  1.00000000
#      n*s02  =  0.07091562 +/- 0.18619081  := 's02 * n_cucu_1'
#      e0     = -0.49309572 +/- 0.64278925  := 'e0'
#      r      =  2.57538897 +/- 0.10413402  := 'reff + delr_cu_1'
#      deltar =  0.01918897 +/- 0.10413402  := 'delr_cu_1'
#      sigma2 =  0.00100000 +/- 0.01620633  := 'sigma2_cu'
#
#  = Path 'O195_1' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#                O      -1.1474,  1.1389, -1.0854  2
#      reff   =  1.94720000
#      degen  =  1.00000000
#      n*s02  =  3.27458578 +/- 0.28311061  := 's02 * n_cuo_1'
#      e0     = -0.49309572 +/- 0.64278925  := 'e0'
#      r      =  1.94847246 +/- 0.00735069  := 'reff + delr_o_1'
#      deltar =  0.00127246 +/- 0.00735069  := 'delr_o_1'
#      sigma2 =  0.00540494 +/- 7.5363e-04  := 'sigma2_o'
#
#  dataset 3:
#  = Path 'Cu256_2' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Copper_cif11145/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#               Cu      -1.8075, -0.0000, -1.8075  1
#      reff   =  2.55620000
#      degen  =  1.00000000
#      n*s02  =  0.05815619 +/- 0.19549796  := 's02 * n_cucu_2'
#      e0     = -0.49309572 +/- 0.64278925  := 'e0'
#      r      =  2.91687869 +/- 0.16850605  := 'reff + delr_cu_2'
#      deltar =  0.36067869 +/- 0.16850605  := 'delr_cu_2'
#      sigma2 =  0.00100000 +/- 0.01620633  := 'sigma2_cu'
#
#  = Path 'O195_2' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#                O      -1.1474,  1.1389, -1.0854  2
#      reff   =  1.94720000
#      degen  =  1.00000000
#      n*s02  =  3.29467447 +/- 0.27689274  := 's02 * n_cuo_2'
#      e0     = -0.49309572 +/- 0.64278925  := 'e0'
#      r      =  1.94730896 +/- 0.00721987  := 'reff + delr_o_2'
#      deltar =  1.0896e-04 +/- 0.00721987  := 'delr_o_2'
#      sigma2 =  0.00540494 +/- 7.5363e-04  := 'sigma2_o'
#
#  dataset 4:
#  = Path 'Cu256_3' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Copper_cif11145/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#               Cu      -1.8075, -0.0000, -1.8075  1
#      reff   =  2.55620000
#      degen  =  1.00000000
#      n*s02  = -0.04661575 +/- 0.13456067  := 's02 * n_cucu_3'
#      e0     = -0.49309572 +/- 0.64278925  := 'e0'
#      r      =  2.46676326 +/- 0.13312618  := 'reff + delr_cu_3'
#      deltar = -0.08943674 +/- 0.13312618  := 'delr_cu_3'
#      sigma2 =  0.00100000 +/- 0.01620633  := 'sigma2_cu'
#
#  = Path 'O195_3' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#                O      -1.1474,  1.1389, -1.0854  2
#      reff   =  1.94720000
#      degen  =  1.00000000
#      n*s02  =  3.22520131 +/- 0.26628073  := 's02 * n_cuo_3'
#      e0     = -0.49309572 +/- 0.64278925  := 'e0'
#      r      =  1.95004808 +/- 0.00716262  := 'reff + delr_o_3'
#      deltar =  0.00284808 +/- 0.00716262  := 'delr_o_3'
#      sigma2 =  0.00540494 +/- 7.5363e-04  := 'sigma2_o'
#
#  dataset 5:
#  = Path 'Cu256_4' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Copper_cif11145/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#               Cu      -1.8075, -0.0000, -1.8075  1
#      reff   =  2.55620000
#      degen  =  1.00000000
#      n*s02  = -0.05171194 +/- 0.14106693  := 's02 * n_cucu_4'
#      e0     = -0.49309572 +/- 0.64278925  := 'e0'
#      r      =  2.43660468 +/- 0.11639112  := 'reff + delr_cu_4'
#      deltar = -0.11959532 +/- 0.11639112  := 'delr_cu_4'
#      sigma2 =  0.00100000 +/- 0.01620633  := 'sigma2_cu'
#
#  = Path 'O195_4' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#                O      -1.1474,  1.1389, -1.0854  2
#      reff   =  1.94720000
#      degen  =  1.00000000
#      n*s02  =  3.20578382 +/- 0.26627567  := 's02 * n_cuo_4'
#      e0     = -0.49309572 +/- 0.64278925  := 'e0'
#      r      =  1.94862760 +/- 0.00721640  := 'reff + delr_o_4'
#      deltar =  0.00142760 +/- 0.00721640  := 'delr_o_4'
#      sigma2 =  0.00540494 +/- 7.5363e-04  := 'sigma2_o'
#
#  dataset 6:
#  = Path 'Cu256_5' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Copper_cif11145/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#               Cu      -1.8075, -0.0000, -1.8075  1
#      reff   =  2.55620000
#      degen  =  1.00000000
#      n*s02  =  0.04120946 +/- 0.12132135  := 's02 * n_cucu_5'
#      e0     = -0.49309572 +/- 0.64278925  := 'e0'
#      r      =  2.27459294 +/- 0.13708910  := 'reff + delr_cu_5'
#      deltar = -0.28160706 +/- 0.13708910  := 'delr_cu_5'
#      sigma2 =  0.00100000 +/- 0.01620633  := 'sigma2_cu'
#
#  = Path 'O195_5' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#                O      -1.1474,  1.1389, -1.0854  2
#      reff   =  1.94720000
#      degen  =  1.00000000
#      n*s02  =  3.35161685 +/- 0.28045601  := 's02 * n_cuo_5'
#      e0     = -0.49309572 +/- 0.64278925  := 'e0'
#      r      =  1.94808161 +/- 0.00756216  := 'reff + delr_o_5'
#      deltar =  8.8161e-04 +/- 0.00756216  := 'delr_o_5'
#      sigma2 =  0.00540494 +/- 7.5363e-04  := 'sigma2_o'
#
#  dataset 7:
#  = Path 'Cu256_6' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Copper_cif11145/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#               Cu      -1.8075, -0.0000, -1.8075  1
#      reff   =  2.55620000
#      degen  =  1.00000000
#      n*s02  = -0.08664519 +/- 0.19551918  := 's02 * n_cucu_6'
#      e0     = -0.49309572 +/- 0.64278925  := 'e0'
#      r      =  2.51849463 +/- 0.06932192  := 'reff + delr_cu_6'
#      deltar = -0.03770537 +/- 0.06932192  := 'delr_cu_6'
#      sigma2 =  0.00100000 +/- 0.01620633  := 'sigma2_cu'
#
#  = Path 'O195_6' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#                O      -1.1474,  1.1389, -1.0854  2
#      reff   =  1.94720000
#      degen  =  1.00000000
#      n*s02  =  3.16125047 +/- 0.24650181  := 's02 * n_cuo_6'
#      e0     = -0.49309572 +/- 0.64278925  := 'e0'
#      r      =  1.95688185 +/- 0.00682387  := 'reff + delr_o_6'
#      deltar =  0.00968185 +/- 0.00682387  := 'delr_o_6'
#      sigma2 =  0.00540494 +/- 7.5363e-04  := 'sigma2_o'
#
#  dataset 8:
#  = Path 'Cu256_7' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Copper_cif11145/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#               Cu      -1.8075, -0.0000, -1.8075  1
#      reff   =  2.55620000
#      degen  =  1.00000000
#      n*s02  = -0.05372309 +/- 0.14297206  := 's02 * n_cucu_7'
#      e0     = -0.49309572 +/- 0.64278925  := 'e0'
#      r      =  2.44753935 +/- 0.11081782  := 'reff + delr_cu_7'
#      deltar = -0.10866065 +/- 0.11081782  := 'delr_cu_7'
#      sigma2 =  0.00100000 +/- 0.01620633  := 'sigma2_cu'
#
#  = Path 'O195_7' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#                O      -1.1474,  1.1389, -1.0854  2
#      reff   =  1.94720000
#      degen  =  1.00000000
#      n*s02  =  3.19080764 +/- 0.26229487  := 's02 * n_cuo_7'
#      e0     = -0.49309572 +/- 0.64278925  := 'e0'
#      r      =  1.95103258 +/- 0.00714962  := 'reff + delr_o_7'
#      deltar =  0.00383258 +/- 0.00714962  := 'delr_o_7'
#      sigma2 =  0.00540494 +/- 7.5363e-04  := 'sigma2_o'
#
#  dataset 9:
#  = Path 'Cu256_8' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Copper_cif11145/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#               Cu      -1.8075, -0.0000, -1.8075  1
#      reff   =  2.55620000
#      degen  =  1.00000000
#      n*s02  = -0.07023444 +/- 0.16900121  := 's02 * n_cucu_8'
#      e0     = -0.49309572 +/- 0.64278925  := 'e0'
#      r      =  2.55263255 +/- 0.08818889  := 'reff + delr_cu_8'
#      deltar = -0.00356745 +/- 0.08818889  := 'delr_cu_8'
#      sigma2 =  0.00100000 +/- 0.01620633  := 'sigma2_cu'
#
#  = Path 'O195_8' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#                O      -1.1474,  1.1389, -1.0854  2
#      reff   =  1.94720000
#      degen  =  1.00000000
#      n*s02  =  3.14866943 +/- 0.24653611  := 's02 * n_cuo_8'
#      e0     = -0.49309572 +/- 0.64278925  := 'e0'
#      r      =  1.95669297 +/- 0.00679985  := 'reff + delr_o_8'
#      deltar =  0.00949297 +/- 0.00679985  := 'delr_o_8'
#      sigma2 =  0.00540494 +/- 7.5363e-04  := 'sigma2_o'
#
#  dataset 10:
#  = Path 'Cu256_9' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Copper_cif11145/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#               Cu      -1.8075, -0.0000, -1.8075  1
#      reff   =  2.55620000
#      degen  =  1.00000000
#      n*s02  = -0.03818016 +/- 0.12614196  := 's02 * n_cucu_9'
#      e0     = -0.49309572 +/- 0.64278925  := 'e0'
#      r      =  2.44509466 +/- 0.16671100  := 'reff + delr_cu_9'
#      deltar = -0.11110534 +/- 0.16671100  := 'delr_cu_9'
#      sigma2 =  0.00100000 +/- 0.01620633  := 'sigma2_cu'
#
#  = Path 'O195_9' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#                O      -1.1474,  1.1389, -1.0854  2
#      reff   =  1.94720000
#      degen  =  1.00000000
#      n*s02  =  3.31145079 +/- 0.27737326  := 's02 * n_cuo_9'
#      e0     = -0.49309572 +/- 0.64278925  := 'e0'
#      r      =  1.94939457 +/- 0.00725229  := 'reff + delr_o_9'
#      deltar =  0.00219457 +/- 0.00725229  := 'delr_o_9'
#      sigma2 =  0.00540494 +/- 7.5363e-04  := 'sigma2_o'
#
# =======================================================

# %%
""" Misc: Extract fitted parameters. """
s02 = _feffit_result.paramgroup.s02
e0 = _feffit_result.paramgroup.e0
delr_Cu256 = _feffit_result.paramgroup.delr_Cu256
sigma2_Cu256 = _feffit_result.paramgroup.sigma2_Cu256

_feffit_result.datasets
