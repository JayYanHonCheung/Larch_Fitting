# %%
from larch.xafs import feffit, feffit_dataset, feffit_transform, feffit_report
from larch.xafs import pre_edge, autobk, xftf, xftr, ff2chi, feffpath
from larch.fitting import  param_group, param
from larch.io import h5group, read_ascii, read_athena, read_xdi, read_specfile, extract_athenagroup

import os
import copy
import h5py
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# [root] WARNING : Larchs apps and shell are not supported due to missing dependencies: cannot import name 'LarchWxApp' from 'larch.wxlib' (D:\Python\Anaconda3\envs\xraylarch\lib\site-packages\larch\wxlib\__init__.py)

# %%
"""
Plan

1. Organise Cu Standard scripts. (Done)
2. Larch fit data_1 of 9. (Done)
3. Organise script for data_1. (Done)
4. Simultaneous fit of data 2 - 9 w/ script. (Done)
5. Compare results with Artemis and Larch (if sigma2 optimised as constrain.) (Not important)
6. Improve fitting by rebinning either in time-axis or EXAFS region. (Didn't work so well.)
7. Improve fitting by cropping and recalibrating all 9000 spectra in DAWN (in LARCH in the future).
8. Fit all 9000 spectra.
9. Adaptive method to choose Cu-Cu and/or Cu-O.
10. Decide fitting parameters: dk, rbkg, dr, etc.
11. Fix double normalisation issue.
12. Maybe different e0, or calibrate properly.
13. Find/create suitable feff model (Hao's suggestion).
14. Improvise, Adapt, Overcome.

"""

# %%
""" 0. Preparing Data. """

data_dir = "data\\time_series_2"
fnames = [fname for fname in os.listdir(data_dir)]
path_list = [os.path.join(data_dir, fname) for fname in fnames]

# %%
""" 1. Batch Reading Data """

# Initialisation
data_list = [read_ascii(fpath, labels="null energy mu") for fpath in path_list]
for data, fname in zip(data_list, fnames):
    data.groupname = fname

# Pre-processing - EXAFS fittings only need a valid k space
    autobk(data, rbkg=1.00) # Need to have option to suppress normalisation in case loaded spectra is already normed
    xftf(data, kmin=3.0, kmax=10, dk=1.0, window="hanning", kweight=2.00)
    xftr(data, rmin=1.0, rmax=4.0, dr=1.0, window="hanning")

# %%
""" Misc: Plotting """
def plot(data_list, index):
    energy = data_list[index].energy
    mu = data_list[index].mu
    norm = data_list[index].norm
    chi = data_list[index].chi
    k = data_list[index].k
    chir_mag = data_list[index].chir_mag
    r = data_list[index].r

    fig, ax = plt.subplots(1, 3, figsize=(15, 5))

    ax[0].plot(energy, norm)
    ax[1].plot(k, chi)
    ax[2].plot(r, chir_mag)
    
plot(data_list, 0)

# %%
""" 2.1 Setup feffit - feffit parameters + FT and fitting space """

# Create feffit Parameter Group to hold fit parameters (Core parameters)
_feffit_params = param_group(s02=param(0.87348, min=0, vary=False),
                             e0=param(0.1, min=-10, max=10, vary=True),
#                              sigma2_cu=param(0.008, min=0.001, max=0.009, vary=True),
                             sigma2_o=param(0.008, min=0.001, max=0.009, vary=True))

# Create feffit Parameter Group to hold fit parameters (Repeating parameters)
data_num = len(data_list)

fit_params = ["n_cuo_", "delr_o_"]
fit_values = [param(1.0, vary=True),
              param(0.001, min=-0.5, max=0.5, vary=True)]

all_fit_params = [param + str(i) for i in range(data_num) for param in fit_params]
all_fit_values = fit_values * data_num

for key, value in zip(all_fit_params, all_fit_values):
    setattr(_feffit_params, key, value)

# Define Fourier transform and fitting space
# Actual FT parameters for EXAFS fitting
_feffit_trans = feffit_transform(kmin=3.000, kmax=10.000, dk=1.0000, kw=2,
                                 window="hanning", fitspace='r', rmin=1.000, rmax=4.000)

# %%
""" 2.2 Setup up paths for all datasets. """

# Create list of base paths
_paths = []

_paths_names = ["O195_"]
_all_paths_names = [pname + str(i) for i in range(data_num) for pname in _paths_names]

path_original = "C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat"
path_new = "C:/Users/user/Downloads/Cu-O_path_at_2_1500.rsp"

_path_o = feffpath(path_new,
               degen=1, e0='e0', sigma2='sigma2_o')

_path_keys = ["label", "s02", "deltar"]
_path_values_o = ["O195_", "s02 * n_cuo_", "delr_o_"]

for i in range(data_num):

    # Setup for Cu-O paths    
    _path_o_temp = copy.deepcopy(_path_o)
    for key, value in zip(_path_keys, _path_values_o):
        setattr(_path_o_temp, key, value + str(i))
        
    _paths_dict = {_paths_names[0] + str(i): _path_o_temp}
    
    _paths.append(_paths_dict)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-dd41d7f90f51> in <module>
#      10 path_new = "C:/Users/user/Downloads/Cu-O_path_at_2_1500.rsp"
#      11
# ---> 12 _path_o = feffpath(path_new,
#      13                degen=1, e0='e0', sigma2='sigma2_o')
#      14
#
# D:\Python\Anaconda3\envs\xraylarch\lib\site-packages\larch\xafs\feffdat.py in feffpath(filename, label, s02, degen, e0, ei, deltar, sigma2, third, fourth, _larch, **kws)
#     542
#     543     """
# --> 544     return FeffPathGroup(filename=filename, label=label, s02=s02,
#     545                          degen=degen, e0=e0, ei=ei, deltar=deltar,
#     546                          sigma2=sigma2, third=third, fourth=fourth)
#
# D:\Python\Anaconda3\envs\xraylarch\lib\site-packages\larch\xafs\feffdat.py in __init__(self, filename, label, s02, degen, e0, ei, deltar, sigma2, third, fourth, _larch, **kws)
#     173         self.spline_coefs = None
#     174
# --> 175         self._feffdat = FeffDatFile(filename=filename)
#     176         self.geom  = self._feffdat.geom
#     177         def_degen  = self._feffdat.degen
#
# D:\Python\Anaconda3\envs\xraylarch\lib\site-packages\larch\xafs\feffdat.py in __init__(self, filename, **kws)
#      35         kwargs.update(kws)
#      36         Group.__init__(self,  **kwargs)
# ---> 37         self._read(filename)
#      38
#      39     def __repr__(self):
#
# D:\Python\Anaconda3\envs\xraylarch\lib\site-packages\larch\xafs\feffdat.py in _read(self, filename)
#     146                     data.append(d)
#     147         data = np.array(data).transpose()
# --> 148         self.k        = data[0]
#     149         self.real_phc = data[1]
#     150         self.mag_feff = data[2]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
_pathsum = ff2chi(_paths[0], paramgroup=_feffit_params)

# %%
""" 2.3 Make dict of paths, sum them using a group of parameters. """
_ff2chi_paths_list = copy.deepcopy(_paths)

for _ff2chi_paths in _ff2chi_paths_list:
    if len(_ff2chi_paths) > 0:
        _pathsum = ff2chi(_ff2chi_paths, paramgroup=_feffit_params)

# %%
""" 2.4 Build and Run feffit dataset"""
_feffit_dataset_list = [feffit_dataset(data=data, paths=path, transform=_feffit_trans) for data, path in zip(data_list, _paths)]
_feffit_result = feffit(_feffit_params, _feffit_dataset_list)

# _feffit_dataset = feffit_dataset(data=data, transform=_feffit_trans, paths=_ff2chi_paths)
# _feffit_result = feffit(_feffit_params, _feffit_dataset) # _feffit_dataset can be a list***

# Insert _feffit_result into self.feffit_history
# if not hasattr(data, 'feffit_history'): 
#     data.feffit_history = []    
# _feffit_result.label = 'Fit %i' % (1+len(data.feffit_history))
# data.feffit_history.insert(0, _feffit_result)

# %%
""" Misc: Plotting fitted results"""
for i, result in enumerate(_feffit_result.datasets):

    data_r = result.data.r
    data_chir_mag = result.data.chir_mag

    fit_r = result.model.r
    fit_chir_mag = result.model.chir_mag

#     a = result.paths["Cu256_" + str(i)].r
#     b = result.paths["Cu256_" + str(i)].chir_mag

    c = result.paths["O195_" + str(i)].r
    d = result.paths["O195_" + str(i)].chir_mag

    fig = plt.figure(figsize=(12, 6))
    plt.plot(fit_r, fit_chir_mag, color="r", label="fit")
    plt.plot(data_r, data_chir_mag, lw=0, marker='o', markersize=3, fillstyle='none', color="k", label="Raw Data")
#     plt.plot(a, b, label="Cu-Cu")
    plt.plot(c, d, label="Cu-O")
    plt.axhline(0, color="k", linestyle=":")
    plt.legend()

# %%
""" Misc: Plotting fitted results"""
for i, result in enumerate(_feffit_result.datasets):

    data_r = result.data.r
    data_chir_mag = result.data.chir_mag

    fit_r = result.model.r
    fit_chir_mag = result.model.chir_mag

#     a = result.paths["Cu256_" + str(i)].r
#     b = result.paths["Cu256_" + str(i)].chir_mag

    c = result.paths["O195_" + str(i)].r
    d = result.paths["O195_" + str(i)].chir_mag

    fig = plt.figure(figsize=(12, 6))
    plt.plot(fit_r, fit_chir_mag, color="r", label="fit")
    plt.plot(data_r, data_chir_mag, lw=0, marker='o', markersize=3, fillstyle='none', color="k", label="Raw Data")
#     plt.plot(a, b, label="Cu-Cu")
    plt.plot(c, d, label="Cu-O")
    plt.axhline(0, color="k", linestyle=":")
    plt.legend()

# %%
""" Misc: Print fitted results. """
print(feffit_report(_feffit_result))
# Out:
# =================== FEFFIT RESULTS ====================
# [[Statistics]]
#    nvarys, npts       =  22, 1960
#    n_independent      =  143.690
#    chi_square         =  412.003625
#    reduced chi_square =  3.38567762
#    r-factor           =  0.03443677
#    Akaike info crit   =  195.359311
#    Bayesian info crit =  260.647814
#
# [[Datasets (10)]]
#  dataset 1:
#    fit space          = 'r'
#    r-range            = 1.000, 4.000
#    k-range            = 3.000, 10.000
#    k window, dk       = 'hanning', 1.000
#    paths used in fit  = ['C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat']
#    k-weight           = 2
#    epsilon_k          = Array(mean=0.00412981, std=0.00557741)
#    epsilon_r          = 0.03679564
#    n_independent      = 14.369
#  dataset 2:
#    fit space          = 'r'
#    r-range            = 1.000, 4.000
#    k-range            = 3.000, 10.000
#    k window, dk       = 'hanning', 1.000
#    paths used in fit  = ['C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat']
#    k-weight           = 2
#    epsilon_k          = Array(mean=0.00438140, std=0.00614010)
#    epsilon_r          = 0.03903725
#    n_independent      = 14.369
#  dataset 3:
#    fit space          = 'r'
#    r-range            = 1.000, 4.000
#    k-range            = 3.000, 10.000
#    k window, dk       = 'hanning', 1.000
#    paths used in fit  = ['C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat']
#    k-weight           = 2
#    epsilon_k          = Array(mean=0.00433064, std=0.00617334)
#    epsilon_r          = 0.03858501
#    n_independent      = 14.369
#  dataset 4:
#    fit space          = 'r'
#    r-range            = 1.000, 4.000
#    k-range            = 3.000, 10.000
#    k window, dk       = 'hanning', 1.000
#    paths used in fit  = ['C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat']
#    k-weight           = 2
#    epsilon_k          = Array(mean=0.00409390, std=0.00562653)
#    epsilon_r          = 0.03647574
#    n_independent      = 14.369
#  dataset 5:
#    fit space          = 'r'
#    r-range            = 1.000, 4.000
#    k-range            = 3.000, 10.000
#    k window, dk       = 'hanning', 1.000
#    paths used in fit  = ['C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat']
#    k-weight           = 2
#    epsilon_k          = Array(mean=0.00403146, std=0.00560151)
#    epsilon_r          = 0.03591938
#    n_independent      = 14.369
#  dataset 6:
#    fit space          = 'r'
#    r-range            = 1.000, 4.000
#    k-range            = 3.000, 10.000
#    k window, dk       = 'hanning', 1.000
#    paths used in fit  = ['C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat']
#    k-weight           = 2
#    epsilon_k          = Array(mean=0.00439942, std=0.00614158)
#    epsilon_r          = 0.03919786
#    n_independent      = 14.369
#  dataset 7:
#    fit space          = 'r'
#    r-range            = 1.000, 4.000
#    k-range            = 3.000, 10.000
#    k window, dk       = 'hanning', 1.000
#    paths used in fit  = ['C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat']
#    k-weight           = 2
#    epsilon_k          = Array(mean=0.00368507, std=0.00510153)
#    epsilon_r          = 0.03283318
#    n_independent      = 14.369
#  dataset 8:
#    fit space          = 'r'
#    r-range            = 1.000, 4.000
#    k-range            = 3.000, 10.000
#    k window, dk       = 'hanning', 1.000
#    paths used in fit  = ['C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat']
#    k-weight           = 2
#    epsilon_k          = Array(mean=0.00396769, std=0.00563341)
#    epsilon_r          = 0.03535122
#    n_independent      = 14.369
#  dataset 9:
#    fit space          = 'r'
#    r-range            = 1.000, 4.000
#    k-range            = 3.000, 10.000
#    k window, dk       = 'hanning', 1.000
#    paths used in fit  = ['C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat']
#    k-weight           = 2
#    epsilon_k          = Array(mean=0.00369401, std=0.00505388)
#    epsilon_r          = 0.03291278
#    n_independent      = 14.369
#  dataset 10:
#    fit space          = 'r'
#    r-range            = 1.000, 4.000
#    k-range            = 3.000, 10.000
#    k window, dk       = 'hanning', 1.000
#    paths used in fit  = ['C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat']
#    k-weight           = 2
#    epsilon_k          = Array(mean=0.00430815, std=0.00615629)
#    epsilon_r          = 0.03838468
#    n_independent      = 14.369
#
# [[Variables]]
#    delr_o_0       = -0.00141153 +/- 0.00584604   (init=  1.0000e-03)
#    delr_o_1       = -0.00350480 +/- 0.00596726   (init=  1.0000e-03)
#    delr_o_2       = -0.00443936 +/- 0.00589414   (init=  1.0000e-03)
#    delr_o_3       = -0.00142582 +/- 0.00577480   (init=  1.0000e-03)
#    delr_o_4       = -0.00288645 +/- 0.00573301   (init=  1.0000e-03)
#    delr_o_5       = -0.00416975 +/- 0.00591875   (init=  1.0000e-03)
#    delr_o_6       =  0.00560109 +/- 0.00549767   (init=  1.0000e-03)
#    delr_o_7       = -4.6973e-04 +/- 0.00569970   (init=  1.0000e-03)
#    delr_o_8       =  0.00551066 +/- 0.00551948   (init=  1.0000e-03)
#    delr_o_9       = -0.00233116 +/- 0.00586408   (init=  1.0000e-03)
#    e0             = -1.53107373 +/- 0.51884418   (init=  0.10000000)
#    n_cuo_0        =  3.81817534 +/- 0.25685212   (init=  1.00000000)
#    n_cuo_1        =  3.91922259 +/- 0.26924024   (init=  1.00000000)
#    n_cuo_2        =  3.93799824 +/- 0.26722486   (init=  1.00000000)
#    n_cuo_3        =  3.85406541 +/- 0.25608059   (init=  1.00000000)
#    n_cuo_4        =  3.82794169 +/- 0.25254769   (init=  1.00000000)
#    n_cuo_5        =  3.97803068 +/- 0.27106692   (init=  1.00000000)
#    n_cuo_6        =  3.78197754 +/- 0.23874411   (init=  1.00000000)
#    n_cuo_7        =  3.81484529 +/- 0.25010344   (init=  1.00000000)
#    n_cuo_8        =  3.76708721 +/- 0.23876692   (init=  1.00000000)
#    n_cuo_9        =  3.95953359 +/- 0.26722807   (init=  1.00000000)
#    s02            =  0.87348000 (fixed)
#    sigma2_o       =  0.00582448 +/- 5.4910e-04   (init=  0.00800000)
#
# [[Correlations]]    (unreported correlations are <  0.100)
#    delr_o_6, e0         =  0.591
#    delr_o_8, e0         =  0.589
#    n_cuo_6, sigma2_o    =  0.587
#    n_cuo_8, sigma2_o    =  0.585
#    delr_o_7, e0         =  0.568
#    n_cuo_7, sigma2_o    =  0.565
#    delr_o_4, e0         =  0.563
#    n_cuo_4, sigma2_o    =  0.562
#    delr_o_3, e0         =  0.560
#    n_cuo_3, sigma2_o    =  0.558
#    delr_o_0, e0         =  0.553
#    n_cuo_0, sigma2_o    =  0.551
#    delr_o_9, e0         =  0.551
#    n_cuo_9, sigma2_o    =  0.549
#    delr_o_2, e0         =  0.547
#    n_cuo_2, sigma2_o    =  0.546
#    delr_o_5, e0         =  0.545
#    n_cuo_5, sigma2_o    =  0.544
#    delr_o_1, e0         =  0.541
#    n_cuo_1, sigma2_o    =  0.540
#    delr_o_6, delr_o_8   =  0.364
#    n_cuo_6, n_cuo_8     =  0.354
#    delr_o_6, delr_o_7   =  0.350
#    delr_o_7, delr_o_8   =  0.349
#    delr_o_4, delr_o_6   =  0.348
#    delr_o_4, delr_o_8   =  0.346
#    delr_o_3, delr_o_6   =  0.346
#    delr_o_3, delr_o_8   =  0.344
#    n_cuo_6, n_cuo_7     =  0.342
#    delr_o_0, delr_o_6   =  0.341
#    delr_o_2, delr_o_5   =  0.311
#    delr_o_1, delr_o_9   =  0.311
#    n_cuo_0, n_cuo_2     =  0.311
#    n_cuo_1, n_cuo_3     =  0.311
#    n_cuo_2, n_cuo_9     =  0.310
#    n_cuo_0, n_cuo_5     =  0.309
#    delr_o_1, delr_o_2   =  0.309
#    n_cuo_5, n_cuo_9     =  0.308
#    delr_o_1, delr_o_5   =  0.308
#    n_cuo_0, n_cuo_1     =  0.307
#    n_cuo_2, n_cuo_5     =  0.307
#    n_cuo_1, n_cuo_9     =  0.306
#    n_cuo_1, n_cuo_2     =  0.304
#    n_cuo_1, n_cuo_5     =  0.303
#    e0, n_cuo_6          = -0.234
#    e0, n_cuo_8          = -0.233
#    e0, sigma2_o         = -0.228
#    e0, n_cuo_7          = -0.226
#    e0, n_cuo_4          = -0.225
#    e0, n_cuo_3          = -0.223
#    e0, n_cuo_0          = -0.221
#    e0, n_cuo_9          = -0.220
#    e0, n_cuo_2          = -0.219
#    e0, n_cuo_5          = -0.218
#    e0, n_cuo_1          = -0.217
#
# [[Paths]]
#  dataset 1:
#  = Path 'O195_0' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#                O      -1.1474,  1.1389, -1.0854  2
#      reff   =  1.94720000
#      degen  =  1.00000000
#      n*s02  =  3.33509980 +/- 0.22435519  := 's02 * n_cuo_0'
#      e0     = -1.53107373 +/- 0.51884418  := 'e0'
#      r      =  1.94578847 +/- 0.00584604  := 'reff + delr_o_0'
#      deltar = -0.00141153 +/- 0.00584604  := 'delr_o_0'
#      sigma2 =  0.00582448 +/- 5.4910e-04  := 'sigma2_o'
#
#  dataset 2:
#  = Path 'O195_1' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#                O      -1.1474,  1.1389, -1.0854  2
#      reff   =  1.94720000
#      degen  =  1.00000000
#      n*s02  =  3.42336255 +/- 0.23517597  := 's02 * n_cuo_1'
#      e0     = -1.53107373 +/- 0.51884418  := 'e0'
#      r      =  1.94369520 +/- 0.00596726  := 'reff + delr_o_1'
#      deltar = -0.00350480 +/- 0.00596726  := 'delr_o_1'
#      sigma2 =  0.00582448 +/- 5.4910e-04  := 'sigma2_o'
#
#  dataset 3:
#  = Path 'O195_2' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#                O      -1.1474,  1.1389, -1.0854  2
#      reff   =  1.94720000
#      degen  =  1.00000000
#      n*s02  =  3.43976270 +/- 0.23341557  := 's02 * n_cuo_2'
#      e0     = -1.53107373 +/- 0.51884418  := 'e0'
#      r      =  1.94276064 +/- 0.00589414  := 'reff + delr_o_2'
#      deltar = -0.00443936 +/- 0.00589414  := 'delr_o_2'
#      sigma2 =  0.00582448 +/- 5.4910e-04  := 'sigma2_o'
#
#  dataset 4:
#  = Path 'O195_3' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#                O      -1.1474,  1.1389, -1.0854  2
#      reff   =  1.94720000
#      degen  =  1.00000000
#      n*s02  =  3.36644905 +/- 0.22368127  := 's02 * n_cuo_3'
#      e0     = -1.53107373 +/- 0.51884418  := 'e0'
#      r      =  1.94577418 +/- 0.00577480  := 'reff + delr_o_3'
#      deltar = -0.00142582 +/- 0.00577480  := 'delr_o_3'
#      sigma2 =  0.00582448 +/- 5.4910e-04  := 'sigma2_o'
#
#  dataset 5:
#  = Path 'O195_4' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#                O      -1.1474,  1.1389, -1.0854  2
#      reff   =  1.94720000
#      degen  =  1.00000000
#      n*s02  =  3.34363051 +/- 0.22059535  := 's02 * n_cuo_4'
#      e0     = -1.53107373 +/- 0.51884418  := 'e0'
#      r      =  1.94431355 +/- 0.00573301  := 'reff + delr_o_4'
#      deltar = -0.00288645 +/- 0.00573301  := 'delr_o_4'
#      sigma2 =  0.00582448 +/- 5.4910e-04  := 'sigma2_o'
#
#  dataset 6:
#  = Path 'O195_5' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#                O      -1.1474,  1.1389, -1.0854  2
#      reff   =  1.94720000
#      degen  =  1.00000000
#      n*s02  =  3.47473024 +/- 0.23677154  := 's02 * n_cuo_5'
#      e0     = -1.53107373 +/- 0.51884418  := 'e0'
#      r      =  1.94303025 +/- 0.00591875  := 'reff + delr_o_5'
#      deltar = -0.00416975 +/- 0.00591875  := 'delr_o_5'
#      sigma2 =  0.00582448 +/- 5.4910e-04  := 'sigma2_o'
#
#  dataset 7:
#  = Path 'O195_6' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#                O      -1.1474,  1.1389, -1.0854  2
#      reff   =  1.94720000
#      degen  =  1.00000000
#      n*s02  =  3.30348174 +/- 0.20853820  := 's02 * n_cuo_6'
#      e0     = -1.53107373 +/- 0.51884418  := 'e0'
#      r      =  1.95280109 +/- 0.00549767  := 'reff + delr_o_6'
#      deltar =  0.00560109 +/- 0.00549767  := 'delr_o_6'
#      sigma2 =  0.00582448 +/- 5.4910e-04  := 'sigma2_o'
#
#  dataset 8:
#  = Path 'O195_7' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#                O      -1.1474,  1.1389, -1.0854  2
#      reff   =  1.94720000
#      degen  =  1.00000000
#      n*s02  =  3.33219106 +/- 0.21846035  := 's02 * n_cuo_7'
#      e0     = -1.53107373 +/- 0.51884418  := 'e0'
#      r      =  1.94673027 +/- 0.00569970  := 'reff + delr_o_7'
#      deltar = -4.6973e-04 +/- 0.00569970  := 'delr_o_7'
#      sigma2 =  0.00582448 +/- 5.4910e-04  := 'sigma2_o'
#
#  dataset 9:
#  = Path 'O195_8' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#                O      -1.1474,  1.1389, -1.0854  2
#      reff   =  1.94720000
#      degen  =  1.00000000
#      n*s02  =  3.29047533 +/- 0.20855813  := 's02 * n_cuo_8'
#      e0     = -1.53107373 +/- 0.51884418  := 'e0'
#      r      =  1.95271066 +/- 0.00551948  := 'reff + delr_o_8'
#      deltar =  0.00551066 +/- 0.00551948  := 'delr_o_8'
#      sigma2 =  0.00582448 +/- 5.4910e-04  := 'sigma2_o'
#
#  dataset 10:
#  = Path 'O195_9' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#                O      -1.1474,  1.1389, -1.0854  2
#      reff   =  1.94720000
#      degen  =  1.00000000
#      n*s02  =  3.45857340 +/- 0.23341838  := 's02 * n_cuo_9'
#      e0     = -1.53107373 +/- 0.51884418  := 'e0'
#      r      =  1.94486884 +/- 0.00586408  := 'reff + delr_o_9'
#      deltar = -0.00233116 +/- 0.00586408  := 'delr_o_9'
#      sigma2 =  0.00582448 +/- 5.4910e-04  := 'sigma2_o'
#
# =======================================================

# %%
""" Misc: Print fitted results. """
print(feffit_report(_feffit_result))
# Out:
# =================== FEFFIT RESULTS ====================
# [[Statistics]]
#    nvarys, npts       =  22, 1960
#    n_independent      =  143.690
#    chi_square         =  492.691586
#    reduced chi_square =  4.04873835
#    r-factor           =  0.04198771
#    Akaike info crit   =  221.058473
#    Bayesian info crit =  286.346977
#
# [[Datasets (10)]]
#  dataset 1:
#    fit space          = 'r'
#    r-range            = 1.000, 4.000
#    k-range            = 3.000, 10.000
#    k window, dk       = 'hanning', 3.000
#    paths used in fit  = ['C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat']
#    k-weight           = 2
#    epsilon_k          = Array(mean=0.00405697, std=0.00559839)
#    epsilon_r          = 0.03614665
#    n_independent      = 14.369
#  dataset 2:
#    fit space          = 'r'
#    r-range            = 1.000, 4.000
#    k-range            = 3.000, 10.000
#    k window, dk       = 'hanning', 3.000
#    paths used in fit  = ['C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat']
#    k-weight           = 2
#    epsilon_k          = Array(mean=0.00431964, std=0.00615823)
#    epsilon_r          = 0.03848700
#    n_independent      = 14.369
#  dataset 3:
#    fit space          = 'r'
#    r-range            = 1.000, 4.000
#    k-range            = 3.000, 10.000
#    k window, dk       = 'hanning', 3.000
#    paths used in fit  = ['C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat']
#    k-weight           = 2
#    epsilon_k          = Array(mean=0.00426331, std=0.00619331)
#    epsilon_r          = 0.03798511
#    n_independent      = 14.369
#  dataset 4:
#    fit space          = 'r'
#    r-range            = 1.000, 4.000
#    k-range            = 3.000, 10.000
#    k window, dk       = 'hanning', 3.000
#    paths used in fit  = ['C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat']
#    k-weight           = 2
#    epsilon_k          = Array(mean=0.00404869, std=0.00563965)
#    epsilon_r          = 0.03607293
#    n_independent      = 14.369
#  dataset 5:
#    fit space          = 'r'
#    r-range            = 1.000, 4.000
#    k-range            = 3.000, 10.000
#    k window, dk       = 'hanning', 3.000
#    paths used in fit  = ['C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat']
#    k-weight           = 2
#    epsilon_k          = Array(mean=0.00401111, std=0.00560743)
#    epsilon_r          = 0.03573810
#    n_independent      = 14.369
#  dataset 6:
#    fit space          = 'r'
#    r-range            = 1.000, 4.000
#    k-range            = 3.000, 10.000
#    k window, dk       = 'hanning', 3.000
#    paths used in fit  = ['C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat']
#    k-weight           = 2
#    epsilon_k          = Array(mean=0.00431931, std=0.00616508)
#    epsilon_r          = 0.03848406
#    n_independent      = 14.369
#  dataset 7:
#    fit space          = 'r'
#    r-range            = 1.000, 4.000
#    k-range            = 3.000, 10.000
#    k window, dk       = 'hanning', 3.000
#    paths used in fit  = ['C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat']
#    k-weight           = 2
#    epsilon_k          = Array(mean=0.00366316, std=0.00510790)
#    epsilon_r          = 0.03263793
#    n_independent      = 14.369
#  dataset 8:
#    fit space          = 'r'
#    r-range            = 1.000, 4.000
#    k-range            = 3.000, 10.000
#    k window, dk       = 'hanning', 3.000
#    paths used in fit  = ['C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat']
#    k-weight           = 2
#    epsilon_k          = Array(mean=0.00393341, std=0.00564353)
#    epsilon_r          = 0.03504579
#    n_independent      = 14.369
#  dataset 9:
#    fit space          = 'r'
#    r-range            = 1.000, 4.000
#    k-range            = 3.000, 10.000
#    k window, dk       = 'hanning', 3.000
#    paths used in fit  = ['C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat']
#    k-weight           = 2
#    epsilon_k          = Array(mean=0.00367142, std=0.00506040)
#    epsilon_r          = 0.03271153
#    n_independent      = 14.369
#  dataset 10:
#    fit space          = 'r'
#    r-range            = 1.000, 4.000
#    k-range            = 3.000, 10.000
#    k window, dk       = 'hanning', 3.000
#    paths used in fit  = ['C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat']
#    k-weight           = 2
#    epsilon_k          = Array(mean=0.00422588, std=0.00618076)
#    epsilon_r          = 0.03765163
#    n_independent      = 14.369
#
# [[Variables]]
#    delr_o_0       =  0.00177697 +/- 0.00653014   (init=  1.0000e-03)
#    delr_o_1       =  1.7878e-04 +/- 0.00668755   (init=  1.0000e-03)
#    delr_o_2       = -8.8657e-04 +/- 0.00659816   (init=  1.0000e-03)
#    delr_o_3       =  0.00180408 +/- 0.00648033   (init=  1.0000e-03)
#    delr_o_4       =  4.3599e-04 +/- 0.00645864   (init=  1.0000e-03)
#    delr_o_5       = -6.4659e-04 +/- 0.00661313   (init=  1.0000e-03)
#    delr_o_6       =  0.00863089 +/- 0.00618672   (init=  1.0000e-03)
#    delr_o_7       =  0.00279728 +/- 0.00640973   (init=  1.0000e-03)
#    delr_o_8       =  0.00861485 +/- 0.00620946   (init=  1.0000e-03)
#    delr_o_9       =  0.00119813 +/- 0.00654972   (init=  1.0000e-03)
#    e0             = -0.64050703 +/- 0.58704842   (init=  0.10000000)
#    n_cuo_0        =  3.66245391 +/- 0.26957349   (init=  1.00000000)
#    n_cuo_1        =  3.75866513 +/- 0.28351109   (init=  1.00000000)
#    n_cuo_2        =  3.77597066 +/- 0.28103038   (init=  1.00000000)
#    n_cuo_3        =  3.69639428 +/- 0.26996564   (init=  1.00000000)
#    n_cuo_4        =  3.67259838 +/- 0.26739916   (init=  1.00000000)
#    n_cuo_5        =  3.81444675 +/- 0.28453137   (init=  1.00000000)
#    n_cuo_6        =  3.62483598 +/- 0.25213217   (init=  1.00000000)
#    n_cuo_7        =  3.65536645 +/- 0.26395717   (init=  1.00000000)
#    n_cuo_8        =  3.61237340 +/- 0.25220761   (init=  1.00000000)
#    n_cuo_9        =  3.79498561 +/- 0.28021441   (init=  1.00000000)
#    s02            =  0.87348000 (fixed)
#    sigma2_o       =  0.00541452 +/- 5.9997e-04   (init=  0.00800000)
#
# [[Correlations]]    (unreported correlations are <  0.100)
#    delr_o_6, e0         =  0.584
#    delr_o_8, e0         =  0.582
#    n_cuo_6, sigma2_o    =  0.578
#    n_cuo_8, sigma2_o    =  0.575
#    delr_o_7, e0         =  0.561
#    n_cuo_7, sigma2_o    =  0.557
#    delr_o_4, e0         =  0.556
#    delr_o_3, e0         =  0.555
#    n_cuo_4, sigma2_o    =  0.552
#    delr_o_0, e0         =  0.550
#    n_cuo_3, sigma2_o    =  0.550
#    delr_o_9, e0         =  0.549
#    n_cuo_0, sigma2_o    =  0.546
#    n_cuo_9, sigma2_o    =  0.544
#    delr_o_2, e0         =  0.544
#    delr_o_5, e0         =  0.543
#    n_cuo_2, sigma2_o    =  0.540
#    n_cuo_5, sigma2_o    =  0.539
#    delr_o_1, e0         =  0.537
#    n_cuo_1, sigma2_o    =  0.533
#    delr_o_6, delr_o_8   =  0.353
#    delr_o_6, delr_o_7   =  0.341
#    n_cuo_6, n_cuo_8     =  0.341
#    delr_o_7, delr_o_8   =  0.340
#    delr_o_4, delr_o_6   =  0.338
#    delr_o_3, delr_o_6   =  0.337
#    delr_o_4, delr_o_8   =  0.337
#    delr_o_3, delr_o_8   =  0.336
#    delr_o_0, delr_o_6   =  0.334
#    delr_o_6, delr_o_9   =  0.333
#    delr_o_0, delr_o_8   =  0.333
#    delr_o_8, delr_o_9   =  0.332
#    delr_o_2, delr_o_6   =  0.330
#    delr_o_5, delr_o_6   =  0.330
#    n_cuo_6, n_cuo_7     =  0.330
#    delr_o_2, delr_o_8   =  0.329
#    delr_o_5, delr_o_8   =  0.329
#    n_cuo_7, n_cuo_8     =  0.328
#    n_cuo_4, n_cuo_6     =  0.327
#    delr_o_1, delr_o_6   =  0.326
#    n_cuo_3, n_cuo_6     =  0.326
#    n_cuo_4, n_cuo_8     =  0.326
#    delr_o_1, delr_o_8   =  0.325
#    delr_o_4, delr_o_7   =  0.325
#    n_cuo_3, n_cuo_8     =  0.325
#    delr_o_3, delr_o_7   =  0.324
#    n_cuo_0, n_cuo_6     =  0.323
#    n_cuo_6, n_cuo_9     =  0.322
#    n_cuo_0, n_cuo_8     =  0.322
#    delr_o_0, delr_o_7   =  0.322
#    n_cuo_8, n_cuo_9     =  0.321
#    delr_o_3, delr_o_4   =  0.321
=
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#                O      -1.1474,  1.1389, -1.0854  2
#      reff   =  1.94720000
#      degen  =  1.00000000
#      n*s02  =  3.19908025 +/- 0.23546705  := 's02 * n_cuo_0'
#      e0     = -0.64050703 +/- 0.58704842  := 'e0'
#      r      =  1.94897697 +/- 0.00653014  := 'reff + delr_o_0'
#      deltar =  0.00177697 +/- 0.00653014  := 'delr_o_0'
#      sigma2 =  0.00541452 +/- 5.9997e-04  := 'sigma2_o'
#
#  dataset 2:
#  = Path 'O195_1' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#                O      -1.1474,  1.1389, -1.0854  2
#      reff   =  1.94720000
#      degen  =  1.00000000
#      n*s02  =  3.28311882 +/- 0.24764127  := 's02 * n_cuo_1'
#      e0     = -0.64050703 +/- 0.58704842  := 'e0'
#      r      =  1.94737878 +/- 0.00668755  := 'reff + delr_o_1'
#      deltar =  1.7878e-04 +/- 0.00668755  := 'delr_o_1'
#      sigma2 =  0.00541452 +/- 5.9997e-04  := 'sigma2_o'
#
#  dataset 3:
#  = Path 'O195_2' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#                O      -1.1474,  1.1389, -1.0854  2
#      reff   =  1.94720000
#      degen  =  1.00000000
#      n*s02  =  3.29823485 +/- 0.24547442  := 's02 * n_cuo_2'
#      e0     = -0.64050703 +/- 0.58704842  := 'e0'
#      r      =  1.94631343 +/- 0.00659816  := 'reff + delr_o_2'
#      deltar = -8.8657e-04 +/- 0.00659816  := 'delr_o_2'
#      sigma2 =  0.00541452 +/- 5.9997e-04  := 'sigma2_o'
#
#  dataset 4:
#  = Path 'O195_3' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#                O      -1.1474,  1.1389, -1.0854  2
#      reff   =  1.94720000
#      degen  =  1.00000000
#      n*s02  =  3.22872647 +/- 0.23580959  := 's02 * n_cuo_3'
#      e0     = -0.64050703 +/- 0.58704842  := 'e0'
#      r      =  1.94900408 +/- 0.00648033  := 'reff + delr_o_3'
#      deltar =  0.00180408 +/- 0.00648033  := 'delr_o_3'
#      sigma2 =  0.00541452 +/- 5.9997e-04  := 'sigma2_o'
#
#  dataset 5:
#  = Path 'O195_4' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#                O      -1.1474,  1.1389, -1.0854  2
#      reff   =  1.94720000
#      degen  =  1.00000000
#      n*s02  =  3.20794123 +/- 0.23356782  := 's02 * n_cuo_4'
#      e0     = -0.64050703 +/- 0.58704842  := 'e0'
#      r      =  1.94763599 +/- 0.00645864  := 'reff + delr_o_4'
#      deltar =  4.3599e-04 +/- 0.00645864  := 'delr_o_4'
#      sigma2 =  0.00541452 +/- 5.9997e-04  := 'sigma2_o'
#
#  dataset 6:
#  = Path 'O195_5' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#                O      -1.1474,  1.1389, -1.0854  2
#      reff   =  1.94720000
#      degen  =  1.00000000
#      n*s02  =  3.33184295 +/- 0.24853246  := 's02 * n_cuo_5'
#      e0     = -0.64050703 +/- 0.58704842  := 'e0'
#      r      =  1.94655341 +/- 0.00661313  := 'reff + delr_o_5'
#      deltar = -6.4659e-04 +/- 0.00661313  := 'delr_o_5'
#      sigma2 =  0.00541452 +/- 5.9997e-04  := 'sigma2_o'
#
#  dataset 7:
#  = Path 'O195_6' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#                O      -1.1474,  1.1389, -1.0854  2
#      reff   =  1.94720000
#      degen  =  1.00000000
#      n*s02  =  3.16622173 +/- 0.22023241  := 's02 * n_cuo_6'
#      e0     = -0.64050703 +/- 0.58704842  := 'e0'
#      r      =  1.95583089 +/- 0.00618672  := 'reff + delr_o_6'
#      deltar =  0.00863089 +/- 0.00618672  := 'delr_o_6'
#      sigma2 =  0.00541452 +/- 5.9997e-04  := 'sigma2_o'
#
#  dataset 8:
#  = Path 'O195_7' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#                O      -1.1474,  1.1389, -1.0854  2
#      reff   =  1.94720000
#      degen  =  1.00000000
#      n*s02  =  3.19288949 +/- 0.23056131  := 's02 * n_cuo_7'
#      e0     = -0.64050703 +/- 0.58704842  := 'e0'
#      r      =  1.94999728 +/- 0.00640973  := 'reff + delr_o_7'
#      deltar =  0.00279728 +/- 0.00640973  := 'delr_o_7'
#      sigma2 =  0.00541452 +/- 5.9997e-04  := 'sigma2_o'
#
#  dataset 9:
#  = Path 'O195_8' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#                O      -1.1474,  1.1389, -1.0854  2
#      reff   =  1.94720000
#      degen  =  1.00000000
#      n*s02  =  3.15533592 +/- 0.22029830  := 's02 * n_cuo_8'
#      e0     = -0.64050703 +/- 0.58704842  := 'e0'
#      r      =  1.95581485 +/- 0.00620946  := 'reff + delr_o_8'
#      deltar =  0.00861485 +/- 0.00620946  := 'delr_o_8'
#      sigma2 =  0.00541452 +/- 5.9997e-04  := 'sigma2_o'
#
#  dataset 10:
#  = Path 'O195_9' =
#     feffdat file = C:/Users/user/larch/feff/Cu1_K_Tenorite_cif11639/feff0001.dat
#     geometry  atom      x        y        z      ipot
#               Cu      -0.0000, -0.0000, -0.0000  0 (absorber)
#                O      -1.1474,  1.1389, -1.0854  2
#      reff   =  1.94720000
#      degen  =  1.00000000
#      n*s02  =  3.31484403 +/- 0.24476168  := 's02 * n_cuo_9'
#      e0     = -0.64050703 +/- 0.58704842  := 'e0'
#      r      =  1.94839813 +/- 0.00654972  := 'reff + delr_o_9'
#      deltar =  0.00119813 +/- 0.00654972  := 'delr_o_9'
#      sigma2 =  0.00541452 +/- 5.9997e-04  := 'sigma2_o'
#
# =======================================================

# %%
""" Misc: Extract fitted parameters. """
s02 = _feffit_result.paramgroup.s02
e0 = _feffit_result.paramgroup.e0
delr_Cu256 = _feffit_result.paramgroup.delr_Cu256
sigma2_Cu256 = _feffit_result.paramgroup.sigma2_Cu256

_feffit_result.datasets
